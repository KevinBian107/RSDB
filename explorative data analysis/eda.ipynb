# %% [markdown]
# # Explorative Data Analysis

# %%
import gzip
from sklearn import svm
import numpy as np
import string
from sklearn import linear_model
from pathlib import Path
import pandas as pd
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## EDA Goals:
# 1. We need to merge the DataFrames to get what we need and identify questions we are interested in.
# 2. Make preprocessing pipeline.

# %% [markdown]
# ## Data Loader
# Please do not push the data to Github (in .gitignore), this will result in large file issues. Actual data set is [here](https://cseweb.ucsd.edu/~jmcauley/datasets.html#google_local)
# - **Data**: Data itself.
#     - The reviews provided by `users`, such as ratings, review text, and pictures.
#     - Directly informs recommendations or sentiment analysis.
#     - `Give what we are looking at from a user's perspective.`
# - **MetaData**: Data that explains about the data.
#     - `Business details`, such as name, address, average rating, category, and operational hours, describing the businesses associated with the reviews.
#     - Enriches the analysis by providing business context.
#     - `Extra information we can us  to perform joins.`

# %%
def parseData(file_path):
    with gzip.open(file_path, 'rt', encoding='utf-8') as f:
        data = [json.loads(line) for line in f]
    return data

base_path = Path.cwd().parent
file_path = base_path / "data" / "data.json.gz"
meta_file_path = base_path / "data" / "metadata.json.gz"

if file_path.exists():
    print(f"Loading data from: {file_path}")
    print(f"Loading metadata from: {meta_file_path}")
    metadata = parseData(meta_file_path)
    data = parseData(file_path)
    print(f"Loaded {len(data)} entries.")
    print(f"Loaded {len(metadata)} entries.")
    
    df = pd.DataFrame(data)
    meta_df = pd.DataFrame(metadata)
    print("DataFrame created. Here's the structure:")
    print(df.info())
    # print(df.head())
    print(meta_df.info())
    # print(meta_df.head())
else:
    print(f"File not found: {file_path}. Please ensure the file exists at the specified location.")
# Out:
# Loading data from: /Users/kevinb/Desktop/cse158/TBR/data/data.json.gz
# Loading metadata from: /Users/kevinb/Desktop/cse158/TBR/data/metadata.json.gz

# %%
meta_df
# Out:
#                                          name  \
# 0                                City Textile
# 1                                San Soo Dang
# 2                                Nova Fabrics
# 3                            Nobel Textile Co
# 4               Matrix International Textiles
# ...                                       ...
# 515956                             McDonald's
# 515957  California Citrus State Historic Park
# 515958                      California Citrus
# 515959             Recreation Park Playground
# 515960              Pasadena Civic Auditorium
#
#                                                   address  \
# 0       City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 1       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 2       Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 3       Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# 4       Matrix International Textiles, 1363 S Bonnie B...
# ...                                                   ...
# 515956     McDonald's, 1728 Lomita Blvd, Lomita, CA 90717
# 515957  California Citrus State Historic Park, 9400 Du...
# 515958  California Citrus, 1999 Van Buren Boulevard, R...
# 515959  Recreation Park Playground, 701-939 Federation...
# 515960  Pasadena Civic Auditorium, 300 E Green St, Pas...
#
#                                       gmap_id  \
# 0       0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 1       0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2        0x80c2c89923b27a41:0x32041559418d447
# 3       0x80c2c632f933b073:0xc31785961fe826a6
# 4       0x80c2cf163db6bc89:0x219484e2edbcfa41
# ...                                       ...
# 515956  0x80dd4a7afea27289:0xe49cfab49567e5cb
# 515957  0x80dcba7983a059af:0x2a006c069483d3d2
# 515958  0x80dcb09e3af6228b:0xa55fc2f742364e02
# 515959  0x80dd31c81d5f153d:0x501886193d0102e7
# 515960  0x80c2c36f7efdaf83:0xd79b6337f9d1ea50
#
#                                               description   latitude  \
# 0                                                    None  34.018891
# 1                                                    None  34.058092
# 2                                                    None  34.023669
# 3                                                    None  34.036694
# 4                                                    None  34.015505
# ...                                                   ...        ...
# 515956  Classic, long-running fast-food chain known fo...  33.797530
# 515957  Park dedicated to preserving the history of Ca...  33.898611
# 515958                                               None  33.898299
# 515959                                               None  33.775862
# 515960                                               None  34.143808
#
#          longitude                                           category  \
# 0      -118.215290                                 [Textile exporter]
# 1      -118.292130                                [Korean restaurant]
# 2      -118.232930                                     [Fabric store]
# 3      -118.249421                                     [Fabric store]
# 4      -118.181839                                     [Fabric store]
# ...            ...                                                ...
# 515956 -118.308527  [Fast food restaurant, Breakfast restaurant, C...
# 515957 -117.425703                         [Park, Tourist attraction]
# 515958 -117.428067                                       [State park]
# 515959 -118.135669                                       [Playground]
# 515960 -118.144360                                [Conference center]
#
#         avg_rating  num_of_reviews price  \
# 0              4.5               6  None
# 1              4.4              18  None
# 2              3.3               6  None
# 3              4.3               7  None
# 4              3.5               6  None
# ...            ...             ...   ...
# 515956         4.1             830     $
# 515957         4.7             763  None
# 515958         4.8              96  None
# 515959         4.3              17  None
# 515960         4.6             506  None
#
#                                                     hours  \
# 0                                                    None
# 1       [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 2       [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 3       [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4       [[Thursday, 8:30AM–5:30PM], [Friday, 8:30AM–5:...
# ...                                                   ...
# 515956  [[Wednesday, 5AM–12AM], [Thursday, 5AM–12AM], ...
# 515957  [[Wednesday, 8AM–5PM], [Thursday, 8AM–5PM], [F...
# 515958                                               None
# 515959                                               None
# 515960                                               None
#
#                                                      MISC  \
# 0                                                    None
# 1       {'Service options': ['Takeout', 'Dine-in', 'De...
# 2       {'Service options': ['In-store shopping'], 'Pa...
# 3                {'Service options': ['In-store pickup']}
# 4       {'Accessibility': ['Wheelchair accessible entr...
# ...                                                   ...
# 515956  {'Service options': ['Curbside pickup', 'No-co...
# 515957  {'Accessibility': ['Wheelchair accessible entr...
# 515958  {'Accessibility': ['Wheelchair accessible entr...
# 515959  {'Accessibility': ['Wheelchair accessible entr...
# 515960  {'Accessibility': ['Wheelchair accessible entr...
#
#                        state  \
# 0                   Open now
# 1          Open ⋅ Closes 6PM
# 2          Open ⋅ Closes 5PM
# 3          Open ⋅ Closes 5PM
# 4       Open ⋅ Closes 5:30PM
# ...                      ...
# 515956                   NaN
# 515957                   NaN
# 515958                   NaN
# 515959                   NaN
# 515960                   NaN
#
#                                          relative_results  \
# 0       [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 1       [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 2       [0x80c2c8811477253f:0x23a8a492df1918f7, 0x80c2...
# 3       [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
# 4       [0x80c2cf042a5d9561:0xd0024ad6f81f1335, 0x80c2...
# ...                                                   ...
# 515956  [0x80dd4a72339feac7:0xcb7398ed660df0b1, 0x80dd...
# 515957  [0x80dcb21eefbd19f5:0x8ebb31f8a91dc2d3, 0x80dc...
# 515958  [0x80dcb09dfb76baef:0x5156f914ebbbe, 0x80dcb1e...
# 515959  [0x80dd31044c86de89:0xea5a9038c8f9e2eb, 0x80dd...
# 515960  [0x80c2c36580edc00d:0x14e659e3b16ec7b6, 0x80c2...
#
#                                                       url
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 1       https://www.google.com/maps/place//data=!4m2!3...
# 2       https://www.google.com/maps/place//data=!4m2!3...
# 3       https://www.google.com/maps/place//data=!4m2!3...
# 4       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                   ...
# 515956  https://www.google.com/maps/place//data=!4m2!3...
# 515957  https://www.google.com/maps/place//data=!4m2!3...
# 515958  https://www.google.com/maps/place//data=!4m2!3...
# 515959  https://www.google.com/maps/place//data=!4m2!3...
# 515960  https://www.google.com/maps/place//data=!4m2!3...
#
# [515961 rows x 15 columns]

# %% [markdown]
# #  Merging
# Metadata provide inofrmation about business, merge on `gmap_id` would be fine.
