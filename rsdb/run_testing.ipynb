# %% [markdown]
# # Running Full Model

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf
import warnings

warnings.filterwarnings("ignore")

from preprocess.data_preprocessing import *
from features.featuring import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/review-California_10.json.gz"
meta_url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/meta-California.json.gz"

cleaned_df = get_single_chunk(url, meta_url)
featured_df = featuring_engineering(cleaned_df)
# Out:
# Loading metadata from: /Users/jack3912/Desktop/RSDB/rsdb/data/metadata.json.gz
# Loaded 463034 metadata entries.
# Processing review data from: /Users/jack3912/Desktop/RSDB/rsdb/data/data.json.gz
# Processed 79763 entries in the first chunk.

# %%
from models.tdlf.temporal_dynamic_v import TemporalDynamicVariants
from models.fpmc.fpmc_v import FPMCVariants

# %%
# Out:
# 6157

# %%
cleaned_df.iloc[10]['gmap_id']
# Out:
# '0x80c2c778e3b73d33:0xbdc58662a4a97d49'

# %%
gmap_id = featured_df.iloc[10]['gmap_id']


category = set(cleaned_df[cleaned_df['gmap_id'] == gmap_id].iloc[0]['category'])

query_data = (cleaned_df[(cleaned_df['category'].apply(lambda x: any(item in category for item in x))) & 
            (cleaned_df['gmap_id'] != gmap_id)
            ])

user_ids = query_data['reviewer_id']
gmap_ids = np.repeat(gmap_id, len(user_ids))

pd.DataFrame({"reviewer_id": user_ids, "gmap_id": gmap_ids})

cleaned_df['reviewer_id'].isin(user_ids)
# Out:
# 0         False
# 2         False
# 4         False
# 6         False
# 8         False
#           ...
# 119008    False
# 119009    False
# 119010    False
# 119011     True
# 119012     True
# Name: reviewer_id, Length: 79763, dtype: bool

# %%
np.unique(featured_df[featured_df['reviewer_id'].isin(user_ids)]['reviewer_id'])
# Out:
# array([1.00033101e+20, 1.00142224e+20, 1.00173084e+20, 1.00183595e+20,
#        1.00412917e+20, 1.00467015e+20, 1.00687217e+20, 1.00748574e+20,
#        1.01004554e+20, 1.01135328e+20, 1.01203895e+20, 1.01223008e+20,
#        1.01338544e+20, 1.01961483e+20, 1.02101606e+20, 1.02141315e+20,
#        1.02253183e+20, 1.02253735e+20, 1.02303843e+20, 1.02435917e+20,
#        1.02439724e+20, 1.02443709e+20, 1.02474628e+20, 1.02652707e+20,
#        1.02708253e+20, 1.02794464e+20, 1.02798398e+20, 1.02846138e+20,
#        1.02856106e+20, 1.02913145e+20, 1.02934391e+20, 1.03018272e+20,
#        1.03116142e+20, 1.03236719e+20, 1.03256471e+20, 1.03284985e+20,
#        1.03388546e+20, 1.03519261e+20, 1.03539202e+20, 1.03906120e+20,
#        1.03924039e+20, 1.04051057e+20, 1.04116731e+20, 1.04199012e+20,
#        1.04255357e+20, 1.04371203e+20, 1.04413475e+20, 1.04434831e+20,
#        1.04446224e+20, 1.04469197e+20, 1.04543583e+20, 1.04566576e+20,
#        1.04892992e+20, 1.04988415e+20, 1.05057610e+20, 1.05122631e+20,
#        1.05195718e+20, 1.05282187e+20, 1.05328767e+20, 1.05381317e+20,
#        1.05404574e+20, 1.05565654e+20, 1.05580254e+20, 1.05620940e+20,
#        1.05677445e+20, 1.05689978e+20, 1.05736700e+20, 1.05782423e+20,
#        1.05828357e+20, 1.06006228e+20, 1.06035631e+20, 1.06093303e+20,
#        1.06181361e+20, 1.06299959e+20, 1.06312698e+20, 1.06368839e+20,
#        1.06408500e+20, 1.06448533e+20, 1.06596221e+20, 1.06620038e+20,
#        1.06662224e+20, 1.06748427e+20, 1.06850282e+20, 1.06896873e+20,
#        1.06907687e+20, 1.07133481e+20, 1.07179610e+20, 1.07212737e+20,
#        1.07372965e+20, 1.07774046e+20, 1.07780605e+20, 1.07832194e+20,
#        1.07893811e+20, 1.07935557e+20, 1.07939685e+20, 1.08047255e+20,
#        1.08094014e+20, 1.08107361e+20, 1.08119494e+20, 1.08124901e+20,
#        1.08130800e+20, 1.08143520e+20, 1.08152656e+20, 1.08189435e+20,
#        1.08210361e+20, 1.08214044e+20, 1.08222774e+20, 1.08236980e+20,
#        1.08241848e+20, 1.08269235e+20, 1.08274163e+20, 1.08275842e+20,
#        1.08276572e+20, 1.08316341e+20, 1.08371038e+20, 1.08384431e+20,
#        1.08390487e+20, 1.08411530e+20, 1.08427081e+20, 1.08436784e+20,
#        1.08438695e+20, 1.08453182e+20, 1.08454758e+20, 1.08465175e+20,
#        1.08501271e+20, 1.08504667e+20, 1.08517997e+20, 1.08547995e+20,
#        1.08570945e+20, 1.08592696e+20, 1.08622927e+20, 1.08630209e+20,
#        1.08644837e+20, 1.08650371e+20, 1.08669176e+20, 1.08676901e+20,
#        1.08719232e+20, 1.08742239e+20, 1.08748519e+20, 1.08776191e+20,
#        1.08792727e+20, 1.08797449e+20, 1.08800063e+20, 1.08805879e+20,
#        1.08817906e+20, 1.08821696e+20, 1.08869675e+20, 1.08869819e+20,
#        1.08878274e+20, 1.08882737e+20, 1.08903536e+20, 1.08905297e+20,
#        1.08912344e+20, 1.08922094e+20, 1.08924054e+20, 1.08924280e+20,
#        1.08929581e+20, 1.08932287e+20, 1.08933181e+20, 1.08941401e+20,
#        1.08944780e+20, 1.08959671e+20, 1.08963780e+20, 1.08966026e+20,
#        1.08967098e+20, 1.08968608e+20, 1.08969741e+20, 1.08973466e+20,
#        1.08976460e+20, 1.08988639e+20, 1.08989027e+20, 1.08989650e+20,
#        1.09010041e+20, 1.09024032e+20, 1.09046700e+20, 1.09052715e+20,
#        1.09115036e+20, 1.09167534e+20, 1.09169517e+20, 1.09213087e+20,
#        1.09479262e+20, 1.09562513e+20, 1.09569152e+20, 1.09584686e+20,
#        1.09652555e+20, 1.09711645e+20, 1.09718631e+20, 1.09788036e+20,
#        1.09888168e+20, 1.09893257e+20, 1.09973149e+20, 1.09991288e+20,
#        1.10005248e+20, 1.10019910e+20, 1.10164872e+20, 1.10166024e+20,
#        1.10172319e+20, 1.10385032e+20, 1.10435803e+20, 1.10512064e+20,
#        1.10627880e+20, 1.10769134e+20, 1.10816663e+20, 1.10819196e+20,
#        1.10827138e+20, 1.10876930e+20, 1.10894805e+20, 1.10924494e+20,
#        1.10925460e+20, 1.11011672e+20, 1.11180483e+20, 1.11222871e+20,
#        1.11493539e+20, 1.11593855e+20, 1.11639142e+20, 1.11774668e+20,
#        1.11804134e+20, 1.11826486e+20, 1.11873738e+20, 1.11879265e+20,
#        1.12038939e+20, 1.12072489e+20, 1.12084260e+20, 1.12128679e+20,
#        1.12187198e+20, 1.12231104e+20, 1.12261508e+20, 1.12408058e+20,
#        1.12460644e+20, 1.12496009e+20, 1.12501835e+20, 1.12585562e+20,
#        1.12585862e+20, 1.12591475e+20, 1.12616715e+20, 1.12622615e+20,
#        1.12751928e+20, 1.12794913e+20, 1.12824308e+20, 1.12918609e+20,
#        1.12966765e+20, 1.13049876e+20, 1.13120981e+20, 1.13124518e+20,
#        1.13242936e+20, 1.13298823e+20, 1.13301986e+20, 1.13351291e+20,
#        1.13363320e+20, 1.13438410e+20, 1.13516077e+20, 1.13528601e+20,
#        1.13686693e+20, 1.13696850e+20, 1.13780636e+20, 1.13795111e+20,
#        1.14044855e+20, 1.14085931e+20, 1.14207317e+20, 1.14292693e+20,
#        1.14359659e+20, 1.14415593e+20, 1.14415661e+20, 1.14648964e+20,
#        1.14765524e+20, 1.14863591e+20, 1.14892359e+20, 1.15064054e+20,
#        1.15121482e+20, 1.15194921e+20, 1.15216131e+20, 1.15233648e+20,
#        1.15420093e+20, 1.15423363e+20, 1.15579898e+20, 1.15695879e+20,
#        1.15739484e+20, 1.15800710e+20, 1.15874542e+20, 1.15956097e+20,
#        1.15988095e+20, 1.16106495e+20, 1.16289966e+20, 1.16356349e+20,
#        1.16413649e+20, 1.16438163e+20, 1.16727743e+20, 1.16783651e+20,
#        1.16877774e+20, 1.16956010e+20, 1.16956381e+20, 1.17103326e+20,
#        1.17126703e+20, 1.17285202e+20, 1.17353975e+20, 1.17355837e+20,
#        1.17356875e+20, 1.17513522e+20, 1.17537265e+20, 1.17557773e+20,
#        1.17584344e+20, 1.17614153e+20, 1.17639617e+20, 1.17746841e+20,
#        1.17950568e+20, 1.18057870e+20, 1.18097671e+20, 1.18156026e+20,
#        1.18162485e+20, 1.18224274e+20, 1.18380018e+20])

# %%
#cleaned_df
featured_df[[
       'gmap_id','isin_category_restaurant', 'isin_category_park', 'isin_category_store',
       'lon_bin_0', 'lon_bin_1', 'lon_bin_2', 'lon_bin_3', 'lon_bin_4',
       'lon_bin_5', 'lon_bin_6', 'lon_bin_7', 'lon_bin_8', 'lon_bin_9',
       'lon_bin_10', 'lon_bin_11', 'lon_bin_12', 'lon_bin_13', 'lon_bin_14',
       'lon_bin_15', 'lon_bin_16', 'lon_bin_17', 'lon_bin_18', 'lon_bin_19',
       'lat_bin_0', 'lat_bin_1', 'lat_bin_2', 'lat_bin_3', 'lat_bin_4',
       'lat_bin_5', 'lat_bin_6', 'lat_bin_7', 'lat_bin_8', 'lat_bin_9',
       'lat_bin_10', 'lat_bin_11', 'lat_bin_12', 'lat_bin_13', 'lat_bin_14',
       'lat_bin_15', 'lat_bin_16', 'lat_bin_17', 'lat_bin_18', 'lat_bin_19',
       'closed_on_weekend', 'weekly_operating_hours']]
# Out:
#                                       gmap_id  isin_category_restaurant  \
# 76001   0x8091aad7a7c4d8f3:0xe4aa0b5a0d2fbcb8                         0
# 83574   0x808fcecafdb31371:0xd9acab442d78ae57                         0
# 12856   0x80c333fe0f143baf:0xd4c005c08bb117d6                         0
# 98068   0x80c3281188d0d8a7:0xd9055ec15e626693                         0
# 13096   0x80db57d6f3f45b17:0xa2494325a8e241cf                         0
# ...                                       ...                       ...
# 64884   0x80c2b66db72fe81b:0xfd5e2f86736d05f4                         0
# 103333  0x80c32fa16dbdf329:0xf8cbe9d0e8fb186c                         0
# 14720   0x80c2d39636c5d87f:0x3d868d3def90a396                         0
# 30486   0x80c36440129b0c55:0x94d1998653c8f3e9                         0
# 73346   0x80dcad1f0724b401:0xb96dfbed33cdf151                         0
#
#         isin_category_park  isin_category_store  lon_bin_0  lon_bin_1  \
# 76001                    0                    0          0          0
# 83574                    0                    0          0          0
# 12856                    0                    0          0          0
# 98068                    0                    1          0          0
# 13096                    0                    0          0          0
# ...                    ...                  ...        ...        ...
# 64884                    0                    0          0          0
# 103333                   0                    0          0          0
# 14720                    0                    0          0          0
# 30486                    0                    0          0          0
# 73346                    0                    0          0          0
#
#         lon_bin_2  lon_bin_3  lon_bin_4  lon_bin_5  ...  lat_bin_14  \
# 76001           0          0          0          0  ...           0
# 83574           0          0          0          1  ...           0
# 12856           0          0          0          0  ...           0
# 98068           0          0          0          0  ...           0
# 13096           0          0          0          0  ...           0
# ...           ...        ...        ...        ...  ...         ...
# 64884           0          0          0          0  ...           0
# 103333          0          0          0          0  ...           0
# 14720           0          0          0          0  ...           0
# 30486           0          0          0          0  ...           0
# 73346           0          0          0          0  ...           0
#
#         lat_bin_15  lat_bin_16  lat_bin_17  lat_bin_18  lat_bin_19  \
# 76001            0           0           0           0           0
# 83574            0           0           0           0           0
# 12856            0           0           0           0           0
# 98068            0           0           0           0           0
# 13096            0           0           0           0           0
# ...            ...         ...         ...         ...         ...
# 64884            0           0           0           0           0
# 103333           0           0           0           0           0
# 14720            0           0           0           0           0
# 30486            0           0           0           0           0
# 73346            0           0           0           0           0
#
#         closed_on_weekend  weekly_operating_hours  time_bin  user_mean_time
# 76001               False                    47.0   2676141        0.634746
# 83574               False                    75.0   2598092        0.029116
# 12856               False                    40.0   2668078        1.160554
# 98068               False                    91.0   2522298       -0.539851
# 13096               False                    77.0   2642849        0.722403
# ...                   ...                     ...       ...             ...
# 64884               False                    70.0   2552542       -0.194477
# 103333              False                    76.0   2649566        0.369517
# 14720               False                    58.0   2540421       -0.523079
# 30486               False                    37.0   2588729       -0.044054
# 73346               False                    51.0   2630418        0.122321
#
# [6157 rows x 48 columns]

# %%
(featured_df[
    featured_df["reviewer_id"].isin(user_ids)
    ].groupby("reviewer_id")["review_time(unix)", "time_bin", "user_mean_time"]
    .max()
    .reset_index())
# Out:
#      reviewer_id  review_time(unix)  time_bin  user_mean_time
# 0   1.005991e+20           1.527870   2693407        1.086192
# 1   1.045146e+20           1.334838   2677177        1.113298
# 2   1.052082e+20           0.155776   2578041        0.158256
# 3   1.066830e+20          -0.066641   2559340       -0.812359
# 4   1.070514e+20           1.315159   2675522        0.498837
# 5   1.073380e+20           1.253202   2670313        0.969364
# 6   1.081906e+20           1.457038   2687451        0.699791
# 7   1.087432e+20           1.369917   2680126        0.329357
# 8   1.095847e+20           1.421188   2684437        1.303051
# 9   1.099124e+20           0.488170   2605989       -0.164302
# 10  1.104117e+20          -0.561751   2517711       -0.748405
# 11  1.107124e+20          -0.019445   2563308       -0.786020
# 12  1.119374e+20           0.050096   2569155       -2.605715
# 13  1.136083e+20           0.609246   2616169       -0.192756
# 14  1.136366e+20           1.405819   2683145        0.552627
# 15  1.171342e+20           1.540409   2694461        1.209219
# 16  1.171529e+20           1.421464   2684460        0.039907
# 17  1.174403e+20           0.561890   2612187        0.293746

# %%
gmap_id
# Out:
# '0x80c2c778e3b73d33:0xbdc58662a4a97d49'

# %%
featured_df[featured_df['gmap_id'] == gmap_id]
# Out:
#        review_time(unix)   reviewer_id                                gmap_id  \
# 78324           0.213150  1.000825e+20  0x80850651331d2eef:0xb70818c48269793c
# 78327          -0.069273  1.045436e+20  0x80850651331d2eef:0xb70818c48269793c
# 78319          -0.124677  1.058767e+20  0x80850651331d2eef:0xb70818c48269793c
#
#        rating  isin_category_restaurant  isin_category_park  \
# 78324       1                         0                   0
# 78327       5                         0                   0
# 78319       5                         0                   0
#
#        isin_category_store  lon_bin_0  lon_bin_1  lon_bin_2  ...  lat_bin_15  \
# 78324                    1          0          0          0  ...           0
# 78327                    1          0          0          0  ...           0
# 78319                    1          0          0          0  ...           0
#
#        lat_bin_16  lat_bin_17  lat_bin_18  lat_bin_19  closed_on_weekend  \
# 78324           0           0           0           0              False
# 78327           0           0           0           0              False
# 78319           0           0           0           0              False
#
#        weekly_operating_hours  time_bin  user_mean_time  \
# 78324                    58.0   2582865       -0.066935
# 78327                    58.0   2559119       -0.191186
# 78319                    58.0   2554461       -0.157916
#
#                                 prev_item_id
# 78324  0x8085a8d0c482a967:0x216f60378adf0fb7
# 78327  0x808fcecbca0be377:0x5eecdc1c5053affc
# 78319  0x80857ec1dc468f9f:0x729aeedcb4e83684
#
# [3 rows x 52 columns]

# %%
(featured_df[
    featured_df["reviewer_id"].isin(user_ids)
    ].loc[
        lambda df: df.groupby("reviewer_id")["review_time(unix)"].idxmax()
    ][['reviewer_id', 'prev_item_id', "review_time(unix)", "time_bin", "user_mean_time"]]
)
# Out:
#          reviewer_id                           prev_item_id  \
# 60162   1.005991e+20  0x80c2b9518dc4f7e7:0xdfbf945567a04fe2
# 60102   1.045146e+20  0x80c2c78f7d79ef43:0x597f758cb18e0dfe
# 60150   1.052082e+20  0x80c2b89039870ea3:0xebbff4cfb499882d
# 60080   1.066830e+20  0x80c29709ad376d05:0xee90ebf6451df205
# 60104   1.070514e+20  0x80c2ba6b7da08fcb:0x402262c4c2f7f82e
# 78112   1.073380e+20  0x80c2b955979b701d:0xb21caed9d84d14eb
# 105395  1.081906e+20  0x80dc06c7bc0b9fbf:0x7ebed41362974411
# 60094   1.087432e+20  0x80c2b89ac0b2c807:0xd5aec6a12f251c54
# 60151   1.095847e+20  0x80c2b8993958e4ff:0x4ad196c6a06d6d29
# 60129   1.099124e+20  0x80c2b62839f3558b:0xf674476def631e61
# 60076   1.104117e+20  0x80c2c78c3f5afd73:0x96605e886c7bc131
# 117375  1.107124e+20  0x808e33849392a70d:0xcc79c75624f4a710
# 117381  1.119374e+20  0x808f7e1b2f6064c7:0x5ecef57fa1a939be
# 105387  1.136083e+20  0x80c2b91f42bf3493:0x648414ec6864d18a
# 57945   1.136366e+20  0x80c2b9518dc4f7e7:0xdfbf945567a04fe2
# 60114   1.171342e+20  0x80c2b6bd96528933:0x11154abe91cc64c0
# 105416  1.171529e+20  0x80c2bb8287a2a2bd:0xb03f41aff062bd42
# 60124   1.174403e+20  0x80c2c778e3b73d33:0xbdc58662a4a97d49
#
#         review_time(unix)  time_bin  user_mean_time
# 60162            1.527870   2693407        1.086192
# 60102            1.334838   2677177        1.113298
# 60150            0.155776   2578041        0.158256
# 60080           -0.066641   2559340       -0.812359
# 60104            1.315159   2675522        0.498837
# 78112            1.253202   2670313        0.969364
# 105395           1.457038   2687451        0.699791
# 60094            1.369917   2680126        0.329357
# 60151            1.421188   2684437        1.303051
# 60129            0.488170   2605989       -0.164302
# 60076           -0.561751   2517711       -0.748405
# 117375          -0.019445   2563308       -0.786020
# 117381           0.050096   2569155       -2.605715
# 105387           0.609246   2616169       -0.192756
# 57945            1.405819   2683145        0.552627
# 60114            1.540409   2694461        1.209219
# 105416           1.421464   2684460        0.039907
# 60124            0.561890   2612187        0.293746

# %%
featured_df[featured_df['reviewer_id'] == featured_df.iloc[10]['reviewer_id']]
# Out:
#        review_time(unix)   reviewer_id                                gmap_id  \
# 80785           0.213148  1.000825e+20  0x8085a8d0c482a967:0x216f60378adf0fb7
# 78324           0.213150  1.000825e+20  0x80850651331d2eef:0xb70818c48269793c
#
#        rating  isin_category_restaurant  isin_category_park  \
# 80785       3                         0                   0
# 78324       1                         0                   0
#
#        isin_category_store  lon_bin_0  lon_bin_1  lon_bin_2  ...  lat_bin_15  \
# 80785                    0          0          0          0  ...           0
# 78324                    1          0          0          0  ...           0
#
#        lat_bin_16  lat_bin_17  lat_bin_18  lat_bin_19  closed_on_weekend  \
# 80785           0           0           0           0              False
# 78324           0           0           0           0              False
#
#        weekly_operating_hours  time_bin  user_mean_time  \
# 80785                    40.0   2582865       -0.066935
# 78324                    58.0   2582865       -0.066935
#
#                                 prev_item_id
# 80785  0x8085068cae8c73db:0x776ca9ffaeb43c00
# 78324  0x8085a8d0c482a967:0x216f60378adf0fb7
#
# [2 rows x 52 columns]

# %% [markdown]
# ***
# # Prepare Features
# ***

# %%
df = featured_df
data_query = df[['gmap_id', 'reviewer_id', 'rating']]
df.info()

# need sequential?
train_df = df.sample(frac=0.8, random_state=42)
test_df = df.drop(train_df.index)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6157 entries, 76001 to 73346
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   review_time(unix)         6157 non-null   float64
#  1   reviewer_id               6157 non-null   float64
#  2   gmap_id                   6157 non-null   object
#  3   rating                    6157 non-null   int64
#  4   isin_category_restaurant  6157 non-null   int64
#  5   isin_category_park        6157 non-null   int64
#  6   isin_category_store       6157 non-null   int64
#  7   lon_bin_0                 6157 non-null   int64
#  8   lon_bin_1                 6157 non-null   int64
#  9   lon_bin_2                 6157 non-null   int64
#  10  lon_bin_3                 6157 non-null   int64
#  11  lon_bin_4                 6157 non-null   int64
#  12  lon_bin_5                 6157 non-null   int64
#  13  lon_bin_6                 6157 non-null   int64
#  14  lon_bin_7                 6157 non-null   int64
#  15  lon_bin_8                 6157 non-null   int64
#  16  lon_bin_9                 6157 non-null   int64
#  17  lon_bin_10                6157 non-null   int64
#  18  lon_bin_11                6157 non-null   int64
#  19  lon_bin_12                6157 non-null   int64
#  20  lon_bin_13                6157 non-null   int64
#  21  lon_bin_14                6157 non-null   int64
#  22  lon_bin_15                6157 non-null   int64
#  23  lon_bin_16                6157 non-null   int64
#  24  lon_bin_17                6157 non-null   int64
#  25  lon_bin_18                6157 non-null   int64
#  26  lon_bin_19                6157 non-null   int64
#  27  lat_bin_0                 6157 non-null   int64
#  28  lat_bin_1                 6157 non-null   int64
#  29  lat_bin_2                 6157 non-null   int64
#  30  lat_bin_3                 6157 non-null   int64
#  31  lat_bin_4                 6157 non-null   int64
#  32  lat_bin_5                 6157 non-null   int64
#  33  lat_bin_6                 6157 non-null   int64
#  34  lat_bin_7                 6157 non-null   int64
#  35  lat_bin_8                 6157 non-null   int64
#  36  lat_bin_9                 6157 non-null   int64
#  37  lat_bin_10                6157 non-null   int64
#  38  lat_bin_11                6157 non-null   int64
#  39  lat_bin_12                6157 non-null   int64
#  40  lat_bin_13                6157 non-null   int64
#  41  lat_bin_14                6157 non-null   int64
#  42  lat_bin_15                6157 non-null   int64
#  43  lat_bin_16                6157 non-null   int64
#  44  lat_bin_17                6157 non-null   int64
#  45  lat_bin_18                6157 non-null   int64
#  46  lat_bin_19                6157 non-null   int64
#  47  closed_on_weekend         6157 non-null   object
#  48  weekly_operating_hours    6157 non-null   float64
#  49  time_bin                  6157 non-null   int64
#  50  user_mean_time            6157 non-null   float64
#  51  prev_item_id              6157 non-null   object
# dtypes: float64(4), int64(45), object(3)
# memory usage: 2.5+ MB

# %%
def tlfm_df_to_tf_dataset(dataframe):
    '''change featuers from data frame to tensorfloe styles'''
    
    return tf.data.Dataset.from_tensor_slices({
        "reviewer_id": dataframe["reviewer_id"].astype(str),
        "gmap_id": dataframe["gmap_id"].astype(str),
        "time": dataframe["review_time(unix)"].astype(float),
        "time_bin": dataframe["time_bin"].astype(float),
        "user_mean_time": dataframe["user_mean_time"],
        "rating": dataframe["rating"],
        "isin_category_restaurant": dataframe["isin_category_restaurant"].astype(float),
        "isin_category_park": dataframe["isin_category_park"].astype(float),
        "isin_category_store": dataframe["isin_category_store"].astype(float),
        "closed_on_weekend": dataframe["closed_on_weekend"].astype(float),
        "weekly_operating_hours": dataframe["weekly_operating_hours"].astype(float),
        
        # Longitude bins
        **{f"lon_bin_{i}": dataframe[f"lon_bin_{i}"].astype(float) for i in range(20) if f"lon_bin_{i}" in dataframe.columns},
        # Latitude bins
        **{f"lat_bin_{i}": dataframe[f"lat_bin_{i}"].astype(float) for i in range(20) if f"lat_bin_{i}" in dataframe.columns},
    })

def fpmc_df_to_tf_dataset(dataframe):
    '''change featuers from data frame to tensorfloe styles'''
    dataframe["reviewer_id"] = dataframe["reviewer_id"].astype(str)
    dataframe["prev_item_id"] = dataframe["prev_item_id"].astype(str)
    dataframe["gmap_id"] = dataframe["gmap_id"].astype(str)
    
    user_lookup = tf.keras.layers.StringLookup(
        vocabulary=dataframe["reviewer_id"].unique(), mask_token=None
    )
    item_lookup = tf.keras.layers.StringLookup(
        vocabulary=dataframe["gmap_id"].unique(), mask_token=None
    )
    
    return tf.data.Dataset.from_tensor_slices({
        "reviewer_id": user_lookup(dataframe["reviewer_id"]),
        "prev_item_id": item_lookup(dataframe["prev_item_id"]),
        "next_item_id": item_lookup(dataframe["gmap_id"]),
        "rating": dataframe["rating"].astype(float),
        "isin_category_restaurant": dataframe["isin_category_restaurant"].astype(float),
        "isin_category_park": dataframe["isin_category_park"].astype(float),
        "isin_category_store": dataframe["isin_category_store"].astype(float),
        "closed_on_weekend": dataframe["closed_on_weekend"].astype(float),
        "weekly_operating_hours": dataframe["weekly_operating_hours"].astype(float),
        
        # Longitude bins
        **{f"lon_bin_{i}": dataframe[f"lon_bin_{i}"].astype(float) for i in range(20) if f"lon_bin_{i}" in dataframe.columns},
        # Latitude bins
        **{f"lat_bin_{i}": dataframe[f"lat_bin_{i}"].astype(float) for i in range(20) if f"lat_bin_{i}" in dataframe.columns},
    })

# %% [markdown]
# ***
# # Description (Many Assumptions)
# ***
#
# ## Temporal Latent Factor Model + Neural Corrolative (Dynamic Latent)
# **Notice that item $i$ refers to the business and user $u$ refers to the user.**
#
# **Modification**:
#
# $$
# \gamma_{u,k}(t) = \gamma_{u,k} + \alpha_{u,k} \cdot \text{dev}_u(t) + \gamma_{u,k,t}
# $$
#
# $$
# \hat{r}_{u,i,t} = \mu + b_i + b_i(t) + b_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_{u,k}(t), \gamma_{i,k})
# $$
#
# **Optimization**:
#
# $$
# \arg \min_{\alpha, \beta, \gamma} \sum_{u,i} \left(\mu + b_i + b_i(t) + b_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_{u,k}(t), \gamma_{i,k}) - R_{u,i} \right)^2 + \lambda \left[ \sum_u \beta_u^2 + \sum_i \beta_i^2 + \sum_i \left\| \gamma_i \right\|_2^2 + \sum_u \left\| \gamma_u \right\|_2^2 \right]
# $$

# %%
train_data = tlfm_df_to_tf_dataset(train_df).shuffle(1024).batch(4096)
test_data = tlfm_df_to_tf_dataset(test_df).batch(4096)

# %%
embedding_dim = 30
dense_units = 30
l2_reg = 0.0201
time_bins= 30
model = TemporalDynamicVariants(l2_reg, dense_units, embedding_dim, data_query, time_bins)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_root_mean_squared_error", 
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2, 
    decay_steps=1000, 
    decay_rate=0.8
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule))
model.fit(train_data, epochs=500, validation_data=test_data, callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 2/2 [==============================] - 1s 276ms/step - root_mean_squared_error: 3.0865 - loss: 4.9693 - regularization_loss: 2.8284 - total_loss: 7.7977 - val_root_mean_squared_error: 2.3011 - val_loss: 5.2952 - val_regularization_loss: 0.9862 - val_total_loss: 6.2814
# Epoch 2/500
# 2/2 [==============================] - 0s 33ms/step - root_mean_squared_error: 2.4009 - loss: 5.6915 - regularization_loss: 0.6039 - total_loss: 6.2954 - val_root_mean_squared_error: 1.5886 - val_loss: 2.5236 - val_regularization_loss: 0.2602 - val_total_loss: 2.7839
# Epoch 3/500
# 2/2 [==============================] - 0s 31ms/step - root_mean_squared_error: 1.5926 - loss: 1.9300 - regularization_loss: 0.3103 - total_loss: 2.2403 - val_root_mean_squared_error: 1.5218 - val_loss: 2.3159 - val_regularization_loss: 0.4897 - val_total_loss: 2.8056
# Epoch 4/500
# 2/2 [==============================] - 0s 31ms/step - root_mean_squared_error: 1.5494 - loss: 3.0153 - regularization_loss: 0.5809 - total_loss: 3.5962 - val_root_mean_squared_error: 1.8459 - val_loss: 3.4074 - val_regularization_loss: 0.6984 - val_total_loss: 4.1059
# Epoch 5/500
# 2/2 [==============================] - 0s 30ms/step - root_mean_squared_error: 1.7558 - loss: 2.6236 - regularization_loss: 0.6955 - total_loss: 3.3190 - val_root_mean_squared_error: 1.2742 - val_loss: 1.6237 - val_regularization_loss: 0.6272 - val_total_loss: 2.2509
# Epoch 6/500
# 2/2 [==============================] - 0s 112ms/step - root_mean_squared_error: 1.2250 - loss: 1.5678 - regularization_loss: 0.5572 - total_loss: 2.1250 - val_root_mean_squared_error: 1.3671 - val_loss: 1.8690 - val_regularization_loss: 0.4059 - val_total_loss: 2.2749
# Epoch 7/500
# 2/2 [==============================] - 0s 29ms/step - root_mean_squared_error: 1.3991 - loss: 2.1608 - regularization_loss: 0.3348 - total_loss: 2.4956 - val_root_mean_squared_error: 1.3830 - val_loss: 1.9128 - val_regularization_loss: 0.2168 - val_total_loss: 2.1296
# Epoch 8/500
# 2/2 [==============================] - 0s 33ms/step - root_mean_squared_error: 1.3656 - loss: 1.6930 - regularization_loss: 0.1818 - total_loss: 1.8748 - val_root_mean_squared_error: 1.1823 - val_loss: 1.3977 - val_regularization_loss: 0.1409 - val_total_loss: 1.5387
# Epoch 9/500
# 2/2 [==============================] - 0s 35ms/step - root_mean_squared_error: 1.1258 - loss: 1.2623 - regularization_loss: 0.1396 - total_loss: 1.4019 - val_root_mean_squared_error: 1.3102 - val_loss: 1.7165 - val_regularization_loss: 0.1485 - val_total_loss: 1.8650
# Epoch 10/500
# 2/2 [==============================] - 0s 27ms/step - root_mean_squared_error: 1.2086 - loss: 1.5417 - regularization_loss: 0.1564 - total_loss: 1.6981 - val_root_mean_squared_error: 1.3197 - val_loss: 1.7415 - val_regularization_loss: 0.1685 - val_total_loss: 1.9100
# Epoch 11/500
# 2/2 [==============================] - 0s 27ms/step - root_mean_squared_error: 1.1853 - loss: 1.3041 - regularization_loss: 0.1690 - total_loss: 1.4731 - val_root_mean_squared_error: 1.1866 - val_loss: 1.4079 - val_regularization_loss: 0.1617 - val_total_loss: 1.5696
# Epoch 12/500
# 2/2 [==============================] - 0s 28ms/step - root_mean_squared_error: 1.0695 - loss: 1.2525 - regularization_loss: 0.1515 - total_loss: 1.4040 - val_root_mean_squared_error: 1.1863 - val_loss: 1.4072 - val_regularization_loss: 0.1260 - val_total_loss: 1.5332
# Epoch 13/500
# 2/2 [==============================] - 0s 29ms/step - root_mean_squared_error: 1.0962 - loss: 1.1895 - regularization_loss: 0.1110 - total_loss: 1.3004 - val_root_mean_squared_error: 1.1956 - val_loss: 1.4294 - val_regularization_loss: 0.0830 - val_total_loss: 1.5124
# Epoch 14/500
# 2/2 [==============================] - 0s 33ms/step - root_mean_squared_error: 1.0918 - loss: 1.1465 - regularization_loss: 0.0724 - total_loss: 1.2190 - val_root_mean_squared_error: 1.1598 - val_loss: 1.3451 - val_regularization_loss: 0.0574 - val_total_loss: 1.4025
# Epoch 15/500
# 2/2 [==============================] - 0s 29ms/step - root_mean_squared_error: 1.0120 - loss: 1.1455 - regularization_loss: 0.0544 - total_loss: 1.2000 - val_root_mean_squared_error: 1.2002 - val_loss: 1.4404 - val_regularization_loss: 0.0528 - val_total_loss: 1.4932
# Epoch 16/500
# 2/2 [==============================] - 0s 38ms/step - root_mean_squared_error: 1.0207 - loss: 1.0637 - regularization_loss: 0.0539 - total_loss: 1.1176 - val_root_mean_squared_error: 1.2301 - val_loss: 1.5130 - val_regularization_loss: 0.0565 - val_total_loss: 1.5695
# Epoch 17/500
# 2/2 [==============================] - 0s 29ms/step - root_mean_squared_error: 1.0247 - loss: 1.0299 - regularization_loss: 0.0572 - total_loss: 1.0871 - val_root_mean_squared_error: 1.1740 - val_loss: 1.3784 - val_regularization_loss: 0.0574 - val_total_loss: 1.4358
# Epoch 18/500
# 2/2 [==============================] - 0s 31ms/step - root_mean_squared_error: 0.9653 - loss: 0.8895 - regularization_loss: 0.0560 - total_loss: 0.9455 - val_root_mean_squared_error: 1.1512 - val_loss: 1.3253 - val_regularization_loss: 0.0516 - val_total_loss: 1.3768
# Epoch 19/500
# 2/2 [==============================] - 0s 28ms/step - root_mean_squared_error: 0.9635 - loss: 0.9701 - regularization_loss: 0.0480 - total_loss: 1.0181 - val_root_mean_squared_error: 1.1558 - val_loss: 1.3360 - val_regularization_loss: 0.0409 - val_total_loss: 1.3769
# Epoch 20/500
# 2/2 [==============================] - 0s 30ms/step - root_mean_squared_error: 0.9617 - loss: 0.9351 - regularization_loss: 0.0378 - total_loss: 0.9729 - val_root_mean_squared_error: 1.1492 - val_loss: 1.3207 - val_regularization_loss: 0.0336 - val_total_loss: 1.3543
# Epoch 21/500
# 2/2 [==============================] - 0s 41ms/step - root_mean_squared_error: 0.9207 - loss: 0.8338 - regularization_loss: 0.0327 - total_loss: 0.8665 - val_root_mean_squared_error: 1.1779 - val_loss: 1.3875 - val_regularization_loss: 0.0322 - val_total_loss: 1.4197
# Epoch 22/500
# 2/2 [==============================] - 0s 31ms/step - root_mean_squared_error: 0.9174 - loss: 0.8499 - regularization_loss: 0.0324 - total_loss: 0.8823 - val_root_mean_squared_error: 1.1829 - val_loss: 1.3992 - val_regularization_loss: 0.0330 - val_total_loss: 1.4322
# Epoch 23/500
# 2/2 [==============================] - 0s 28ms/step - root_mean_squared_error: 0.9050 - loss: 0.7878 - regularization_loss: 0.0332 - total_loss: 0.8210 - val_root_mean_squared_error: 1.1543 - val_loss: 1.3324 - val_regularization_loss: 0.0337 - val_total_loss: 1.3661
# Epoch 24/500
# 2/2 [==============================] - 0s 32ms/step - root_mean_squared_error: 0.8779 - loss: 0.7361 - regularization_loss: 0.0335 - total_loss: 0.7696 - val_root_mean_squared_error: 1.1451 - val_loss: 1.3112 - val_regularization_loss: 0.0324 - val_total_loss: 1.3435
# Epoch 25/500
# 2/2 [==============================] - 0s 31ms/step - root_mean_squared_error: 0.8749 - loss: 0.7224 - regularization_loss: 0.0312 - total_loss: 0.7535 - val_root_mean_squared_error: 1.1451 - val_loss: 1.3111 - val_regularization_loss: 0.0288 - val_total_loss: 1.3400
# Epoch 26/500
# 2/2 [==============================] - 0s 28ms/step - root_mean_squared_error: 0.8590 - loss: 0.7382 - regularization_loss: 0.0278 - total_loss: 0.7660 - val_root_mean_squared_error: 1.1552 - val_loss: 1.3345 - val_regularization_loss: 0.0269 - val_total_loss: 1.3614
# Epoch 27/500
# 2/2 [==============================] - 0s 29ms/step - root_mean_squared_error: 0.8411 - loss: 0.7177 - regularization_loss: 0.0269 - total_loss: 0.7445 - val_root_mean_squared_error: 1.1701 - val_loss: 1.3692 - val_regularization_loss: 0.0276 - val_total_loss: 1.3968
# Epoch 28/500
# 2/2 [==============================] - 0s 27ms/step - root_mean_squared_error: 0.8343 - loss: 0.6745 - regularization_loss: 0.0281 - total_loss: 0.7027 - val_root_mean_squared_error: 1.1623 - val_loss: 1.3510 - val_regularization_loss: 0.0295 - val_total_loss: 1.3805
# Epoch 29/500
# 2/2 [==============================] - 0s 32ms/step - root_mean_squared_error: 0.8168 - loss: 0.6583 - regularization_loss: 0.0301 - total_loss: 0.6885 - val_root_mean_squared_error: 1.1507 - val_loss: 1.3240 - val_regularization_loss: 0.0315 - val_total_loss: 1.3555
# Epoch 30/500
# 2/2 [==============================] - 0s 30ms/step - root_mean_squared_error: 0.8039 - loss: 0.6193 - regularization_loss: 0.0317 - total_loss: 0.6510 - val_root_mean_squared_error: 1.1500 - val_loss: 1.3226 - val_regularization_loss: 0.0318 - val_total_loss: 1.3544
# Epoch 31/500
# 2/2 [==============================] - 0s 31ms/step - root_mean_squared_error: 0.7923 - loss: 0.6623 - regularization_loss: 0.0315 - total_loss: 0.6937 - val_root_mean_squared_error: 1.1592 - val_loss: 1.3437 - val_regularization_loss: 0.0317 - val_total_loss: 1.3755
# Epoch 32/500
# 2/2 [==============================] - 0s 30ms/step - root_mean_squared_error: 0.7793 - loss: 0.5796 - regularization_loss: 0.0321 - total_loss: 0.6117 - val_root_mean_squared_error: 1.1696 - val_loss: 1.3680 - val_regularization_loss: 0.0334 - val_total_loss: 1.4014
# Epoch 33/500
# 2/2 [==============================] - 0s 28ms/step - root_mean_squared_error: 0.7696 - loss: 0.5838 - regularization_loss: 0.0340 - total_loss: 0.6178 - val_root_mean_squared_error: 1.1636 - val_loss: 1.3540 - val_regularization_loss: 0.0358 - val_total_loss: 1.3897
# Epoch 34/500
# 2/2 [==============================] - 0s 36ms/step - root_mean_squared_error: 0.7540 - loss: 0.5560 - regularization_loss: 0.0365 - total_loss: 0.5925 - val_root_mean_squared_error: 1.1565 - val_loss: 1.3375 - val_regularization_loss: 0.0381 - val_total_loss: 1.3756

# %%
test_metrics = model.evaluate(test_data, return_dict=True)
print(f"Test RMSE: {test_metrics['root_mean_squared_error']}")

predictions = []
actual_ratings = []
for batch in test_data:
    predicted_ratings = model(batch).numpy()
    actual_ratings.extend(batch["rating"].numpy())
    predictions.extend(predicted_ratings)

predictions = np.array(predictions)
actual_ratings = np.array(actual_ratings)

rmse = np.sqrt(np.mean((predictions - actual_ratings) ** 2))
print(f"RECHECK RMSE: {rmse}")

if np.all(actual_ratings == actual_ratings.round()):
    correct = np.mean(predictions.round() == actual_ratings)
    print(f"Rounded Accuracy: {correct}")
else:
    print("Actual ratings are not integers, skipping rounded accuracy calculation.")
# Out:
# 1/1 [==============================] - 0s 17ms/step - root_mean_squared_error: 1.1442 - loss: 1.3091 - regularization_loss: 0.0301 - total_loss: 1.3392
# Test RMSE: 1.1441680192947388
# RECHECK RMSE: 1.1441680726347163
# Rounded Accuracy: 0.27213647441104794

# %% [markdown]
# ***
# # Description (Less Assumptions)
# ***
#
# # Factorized Personalized Markov Chain
#
# $$
# p(i_{t+1} \mid i_t, u) = p(i_{t+1} \mid i_t, u)
# $$
#
# In Factorized Personalized Markov Chain (FPMC), we do this calculation by:
#
# $$
# f(i \mid u, j) = \underbrace{\gamma_{ui} \cdot \gamma_{iu}}_{\mathclap{f(i \mid u)}} + \underbrace{\gamma_{ij} \cdot \gamma_{ji}}_{\mathclap{f(i \mid j)}} + \underbrace{\gamma_{uj} \cdot \gamma_{ju}}_{\mathclap{f(u, j)}}.
# $$
#
# Neglecting independent terms:
#
# $$
# f(i \mid u, j) =
# \underbrace{\gamma_{ui} \cdot \gamma_{iu}}_{\text{user's compatibility with the next item}} +
# \underbrace{\gamma_{ij} \cdot \gamma_{ji}}_{\text{next item's compatibility with the previous item}}
# $$

# %%
train_data = fpmc_df_to_tf_dataset(train_df).shuffle(1024).batch(4096)
test_data = fpmc_df_to_tf_dataset(test_df).batch(4096)

# %%
embedding_dim = 32
l2_reg = 0.0201
lr = 1e-3
model = FPMCVariants(l2_reg=l2_reg, embedding_dim=embedding_dim, data_query=data_query)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_root_mean_squared_error", 
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr))

history = model.fit(
    train_data, 
    validation_data=test_data, 
    epochs=500, 
    callbacks=[early_stopping]
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 2/2 [==============================] - 1s 242ms/step - root_mean_squared_error: 4.8663 - loss: 23.8435 - regularization_loss: 6.7936 - total_loss: 30.6371 - val_root_mean_squared_error: 4.7223 - val_loss: 22.3001 - val_regularization_loss: 6.3276 - val_total_loss: 28.6276
# Epoch 2/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 4.7411 - loss: 22.2746 - regularization_loss: 6.1063 - total_loss: 28.3809 - val_root_mean_squared_error: 4.5979 - val_loss: 21.1405 - val_regularization_loss: 5.6783 - val_total_loss: 26.8188
# Epoch 3/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 4.6179 - loss: 20.8812 - regularization_loss: 5.4758 - total_loss: 26.3569 - val_root_mean_squared_error: 4.4744 - val_loss: 20.0200 - val_regularization_loss: 5.0846 - val_total_loss: 25.1046
# Epoch 4/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 4.4954 - loss: 20.1587 - regularization_loss: 4.9002 - total_loss: 25.0588 - val_root_mean_squared_error: 4.3530 - val_loss: 18.9488 - val_regularization_loss: 4.5446 - val_total_loss: 23.4934
# Epoch 5/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 4.3754 - loss: 18.9444 - regularization_loss: 4.3776 - total_loss: 23.3220 - val_root_mean_squared_error: 4.2337 - val_loss: 17.9245 - val_regularization_loss: 4.0562 - val_total_loss: 21.9806
# Epoch 6/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 4.2572 - loss: 18.2556 - regularization_loss: 3.9057 - total_loss: 22.1612 - val_root_mean_squared_error: 4.1171 - val_loss: 16.9504 - val_regularization_loss: 3.6166 - val_total_loss: 20.5670
# Epoch 7/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 4.1418 - loss: 16.9622 - regularization_loss: 3.4817 - total_loss: 20.4439 - val_root_mean_squared_error: 4.0028 - val_loss: 16.0224 - val_regularization_loss: 3.2230 - val_total_loss: 19.2454
# Epoch 8/500
# 2/2 [==============================] - 0s 26ms/step - root_mean_squared_error: 4.0287 - loss: 16.1704 - regularization_loss: 3.1027 - total_loss: 19.2731 - val_root_mean_squared_error: 3.8924 - val_loss: 15.1510 - val_regularization_loss: 2.8723 - val_total_loss: 18.0234
# Epoch 9/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 3.9194 - loss: 15.5178 - regularization_loss: 2.7655 - total_loss: 18.2833 - val_root_mean_squared_error: 3.7851 - val_loss: 14.3268 - val_regularization_loss: 2.5614 - val_total_loss: 16.8882
# Epoch 10/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 3.8134 - loss: 14.4526 - regularization_loss: 2.4670 - total_loss: 16.9196 - val_root_mean_squared_error: 3.6801 - val_loss: 13.5434 - val_regularization_loss: 2.2870 - val_total_loss: 15.8304
# Epoch 11/500
# 2/2 [==============================] - 0s 24ms/step - root_mean_squared_error: 3.7095 - loss: 13.8583 - regularization_loss: 2.2040 - total_loss: 16.0622 - val_root_mean_squared_error: 3.5774 - val_loss: 12.7976 - val_regularization_loss: 2.0459 - val_total_loss: 14.8436
# Epoch 12/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 3.6079 - loss: 13.2205 - regularization_loss: 1.9733 - total_loss: 15.1937 - val_root_mean_squared_error: 3.4778 - val_loss: 12.0952 - val_regularization_loss: 1.8351 - val_total_loss: 13.9304
# Epoch 13/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 3.5097 - loss: 12.1915 - regularization_loss: 1.7718 - total_loss: 13.9633 - val_root_mean_squared_error: 3.3815 - val_loss: 11.4347 - val_regularization_loss: 1.6516 - val_total_loss: 13.0863
# Epoch 14/500
# 2/2 [==============================] - 0s 24ms/step - root_mean_squared_error: 3.4144 - loss: 11.4640 - regularization_loss: 1.5967 - total_loss: 13.0607 - val_root_mean_squared_error: 3.2882 - val_loss: 10.8121 - val_regularization_loss: 1.4926 - val_total_loss: 12.3046
# Epoch 15/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 3.3223 - loss: 10.6612 - regularization_loss: 1.4451 - total_loss: 12.1063 - val_root_mean_squared_error: 3.1981 - val_loss: 10.2281 - val_regularization_loss: 1.3552 - val_total_loss: 11.5833
# Epoch 16/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 3.2331 - loss: 10.3660 - regularization_loss: 1.3144 - total_loss: 11.6804 - val_root_mean_squared_error: 3.1115 - val_loss: 9.6812 - val_regularization_loss: 1.2372 - val_total_loss: 10.9184
# Epoch 17/500
# 2/2 [==============================] - 0s 24ms/step - root_mean_squared_error: 3.1472 - loss: 10.0244 - regularization_loss: 1.2021 - total_loss: 11.2265 - val_root_mean_squared_error: 3.0279 - val_loss: 9.1683 - val_regularization_loss: 1.1360 - val_total_loss: 10.3042
# Epoch 18/500
# 2/2 [==============================] - 0s 26ms/step - root_mean_squared_error: 3.0646 - loss: 9.2694 - regularization_loss: 1.1060 - total_loss: 10.3753 - val_root_mean_squared_error: 2.9473 - val_loss: 8.6865 - val_regularization_loss: 1.0495 - val_total_loss: 9.7360
# Epoch 19/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 2.9849 - loss: 8.6931 - regularization_loss: 1.0239 - total_loss: 9.7171 - val_root_mean_squared_error: 2.8693 - val_loss: 8.2330 - val_regularization_loss: 0.9758 - val_total_loss: 9.2088
# Epoch 20/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 2.9078 - loss: 8.2262 - regularization_loss: 0.9540 - total_loss: 9.1802 - val_root_mean_squared_error: 2.7947 - val_loss: 7.8106 - val_regularization_loss: 0.9130 - val_total_loss: 8.7236
# Epoch 21/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 2.8339 - loss: 7.8897 - regularization_loss: 0.8945 - total_loss: 8.7842 - val_root_mean_squared_error: 2.7230 - val_loss: 7.4149 - val_regularization_loss: 0.8597 - val_total_loss: 8.2746
# Epoch 22/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 2.7628 - loss: 7.7465 - regularization_loss: 0.8440 - total_loss: 8.5905 - val_root_mean_squared_error: 2.6542 - val_loss: 7.0447 - val_regularization_loss: 0.8144 - val_total_loss: 7.8591
# Epoch 23/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 2.6949 - loss: 7.3181 - regularization_loss: 0.8010 - total_loss: 8.1191 - val_root_mean_squared_error: 2.5880 - val_loss: 6.6977 - val_regularization_loss: 0.7758 - val_total_loss: 7.4735
# Epoch 24/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 2.6296 - loss: 6.7898 - regularization_loss: 0.7644 - total_loss: 7.5542 - val_root_mean_squared_error: 2.5244 - val_loss: 6.3726 - val_regularization_loss: 0.7429 - val_total_loss: 7.1154
# Epoch 25/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 2.5668 - loss: 6.6807 - regularization_loss: 0.7331 - total_loss: 7.4138 - val_root_mean_squared_error: 2.4637 - val_loss: 6.0700 - val_regularization_loss: 0.7147 - val_total_loss: 6.7847
# Epoch 26/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 2.5069 - loss: 6.2808 - regularization_loss: 0.7063 - total_loss: 6.9871 - val_root_mean_squared_error: 2.4052 - val_loss: 5.7848 - val_regularization_loss: 0.6904 - val_total_loss: 6.4752
# Epoch 27/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 2.4491 - loss: 5.8449 - regularization_loss: 0.6831 - total_loss: 6.5280 - val_root_mean_squared_error: 2.3484 - val_loss: 5.5150 - val_regularization_loss: 0.6693 - val_total_loss: 6.1843
# Epoch 28/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 2.3930 - loss: 5.6970 - regularization_loss: 0.6630 - total_loss: 6.3599 - val_root_mean_squared_error: 2.2936 - val_loss: 5.2608 - val_regularization_loss: 0.6509 - val_total_loss: 5.9117
# Epoch 29/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 2.3388 - loss: 5.4389 - regularization_loss: 0.6453 - total_loss: 6.0843 - val_root_mean_squared_error: 2.2410 - val_loss: 5.0220 - val_regularization_loss: 0.6346 - val_total_loss: 5.6566
# Epoch 30/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 2.2867 - loss: 5.3418 - regularization_loss: 0.6297 - total_loss: 5.9715 - val_root_mean_squared_error: 2.1902 - val_loss: 4.7968 - val_regularization_loss: 0.6201 - val_total_loss: 5.4169
# Epoch 31/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 2.2364 - loss: 5.1000 - regularization_loss: 0.6156 - total_loss: 5.7156 - val_root_mean_squared_error: 2.1411 - val_loss: 4.5842 - val_regularization_loss: 0.6070 - val_total_loss: 5.1912
# Epoch 32/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 2.1880 - loss: 4.7656 - regularization_loss: 0.6029 - total_loss: 5.3685 - val_root_mean_squared_error: 2.0938 - val_loss: 4.3841 - val_regularization_loss: 0.5950 - val_total_loss: 4.9791
# Epoch 33/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 2.1411 - loss: 4.6086 - regularization_loss: 0.5912 - total_loss: 5.1999 - val_root_mean_squared_error: 2.0487 - val_loss: 4.1973 - val_regularization_loss: 0.5839 - val_total_loss: 4.7811
# Epoch 34/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 2.0965 - loss: 4.4171 - regularization_loss: 0.5804 - total_loss: 4.9975 - val_root_mean_squared_error: 2.0057 - val_loss: 4.0228 - val_regularization_loss: 0.5735 - val_total_loss: 4.5963
# Epoch 35/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 2.0539 - loss: 4.1439 - regularization_loss: 0.5702 - total_loss: 4.7141 - val_root_mean_squared_error: 1.9644 - val_loss: 3.8590 - val_regularization_loss: 0.5637 - val_total_loss: 4.4227
# Epoch 36/500
# 2/2 [==============================] - 0s 25ms/step - root_mean_squared_error: 2.0127 - loss: 4.1917 - regularization_loss: 0.5606 - total_loss: 4.7522 - val_root_mean_squared_error: 1.9248 - val_loss: 3.7048 - val_regularization_loss: 0.5544 - val_total_loss: 4.2591
# Epoch 37/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.9735 - loss: 3.9072 - regularization_loss: 0.5514 - total_loss: 4.4586 - val_root_mean_squared_error: 1.8866 - val_loss: 3.5591 - val_regularization_loss: 0.5454 - val_total_loss: 4.1046
# Epoch 38/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.9355 - loss: 3.8659 - regularization_loss: 0.5425 - total_loss: 4.4084 - val_root_mean_squared_error: 1.8500 - val_loss: 3.4225 - val_regularization_loss: 0.5368 - val_total_loss: 3.9594
# Epoch 39/500
# 2/2 [==============================] - 0s 24ms/step - root_mean_squared_error: 1.8993 - loss: 3.4718 - regularization_loss: 0.5340 - total_loss: 4.0058 - val_root_mean_squared_error: 1.8151 - val_loss: 3.2945 - val_regularization_loss: 0.5285 - val_total_loss: 3.8230
# Epoch 40/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.8644 - loss: 3.4230 - regularization_loss: 0.5258 - total_loss: 3.9487 - val_root_mean_squared_error: 1.7818 - val_loss: 3.1748 - val_regularization_loss: 0.5204 - val_total_loss: 3.6952
# Epoch 41/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.8311 - loss: 3.3647 - regularization_loss: 0.5178 - total_loss: 3.8824 - val_root_mean_squared_error: 1.7499 - val_loss: 3.0623 - val_regularization_loss: 0.5126 - val_total_loss: 3.5748
# Epoch 42/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.7992 - loss: 3.3565 - regularization_loss: 0.5100 - total_loss: 3.8664 - val_root_mean_squared_error: 1.7198 - val_loss: 2.9578 - val_regularization_loss: 0.5049 - val_total_loss: 3.4627
# Epoch 43/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.7691 - loss: 3.2129 - regularization_loss: 0.5024 - total_loss: 3.7153 - val_root_mean_squared_error: 1.6910 - val_loss: 2.8594 - val_regularization_loss: 0.4974 - val_total_loss: 3.3568
# Epoch 44/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.7402 - loss: 3.1704 - regularization_loss: 0.4949 - total_loss: 3.6653 - val_root_mean_squared_error: 1.6635 - val_loss: 2.7671 - val_regularization_loss: 0.4901 - val_total_loss: 3.2572
# Epoch 45/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.7127 - loss: 2.9547 - regularization_loss: 0.4877 - total_loss: 3.4424 - val_root_mean_squared_error: 1.6373 - val_loss: 2.6807 - val_regularization_loss: 0.4829 - val_total_loss: 3.1636
# Epoch 46/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.6865 - loss: 2.7703 - regularization_loss: 0.4806 - total_loss: 3.2509 - val_root_mean_squared_error: 1.6122 - val_loss: 2.5993 - val_regularization_loss: 0.4759 - val_total_loss: 3.0752
# Epoch 47/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.6613 - loss: 2.8170 - regularization_loss: 0.4736 - total_loss: 3.2907 - val_root_mean_squared_error: 1.5884 - val_loss: 2.5231 - val_regularization_loss: 0.4691 - val_total_loss: 2.9921
# Epoch 48/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.6372 - loss: 2.8846 - regularization_loss: 0.4668 - total_loss: 3.3514 - val_root_mean_squared_error: 1.5656 - val_loss: 2.4512 - val_regularization_loss: 0.4624 - val_total_loss: 2.9136
# Epoch 49/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.6142 - loss: 2.7816 - regularization_loss: 0.4602 - total_loss: 3.2418 - val_root_mean_squared_error: 1.5440 - val_loss: 2.3839 - val_regularization_loss: 0.4558 - val_total_loss: 2.8397
# Epoch 50/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.5923 - loss: 2.6121 - regularization_loss: 0.4537 - total_loss: 3.0658 - val_root_mean_squared_error: 1.5233 - val_loss: 2.3203 - val_regularization_loss: 0.4494 - val_total_loss: 2.7697
# Epoch 51/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.5712 - loss: 2.6292 - regularization_loss: 0.4473 - total_loss: 3.0765 - val_root_mean_squared_error: 1.5034 - val_loss: 2.2603 - val_regularization_loss: 0.4431 - val_total_loss: 2.7034
# Epoch 52/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.5510 - loss: 2.5377 - regularization_loss: 0.4410 - total_loss: 2.9787 - val_root_mean_squared_error: 1.4845 - val_loss: 2.2038 - val_regularization_loss: 0.4369 - val_total_loss: 2.6407
# Epoch 53/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.5316 - loss: 2.4120 - regularization_loss: 0.4349 - total_loss: 2.8469 - val_root_mean_squared_error: 1.4665 - val_loss: 2.1505 - val_regularization_loss: 0.4309 - val_total_loss: 2.5814
# Epoch 54/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.5132 - loss: 2.2483 - regularization_loss: 0.4289 - total_loss: 2.6772 - val_root_mean_squared_error: 1.4494 - val_loss: 2.1007 - val_regularization_loss: 0.4250 - val_total_loss: 2.5256
# Epoch 55/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.4955 - loss: 2.2571 - regularization_loss: 0.4230 - total_loss: 2.6802 - val_root_mean_squared_error: 1.4332 - val_loss: 2.0541 - val_regularization_loss: 0.4192 - val_total_loss: 2.4732
# Epoch 56/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.4788 - loss: 2.2154 - regularization_loss: 0.4173 - total_loss: 2.6326 - val_root_mean_squared_error: 1.4179 - val_loss: 2.0104 - val_regularization_loss: 0.4135 - val_total_loss: 2.4239
# Epoch 57/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.4627 - loss: 2.2691 - regularization_loss: 0.4116 - total_loss: 2.6808 - val_root_mean_squared_error: 1.4033 - val_loss: 1.9692 - val_regularization_loss: 0.4079 - val_total_loss: 2.3771
# Epoch 58/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.4475 - loss: 2.1538 - regularization_loss: 0.4061 - total_loss: 2.5598 - val_root_mean_squared_error: 1.3896 - val_loss: 1.9310 - val_regularization_loss: 0.4024 - val_total_loss: 2.3334
# Epoch 59/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.4332 - loss: 2.1120 - regularization_loss: 0.4007 - total_loss: 2.5126 - val_root_mean_squared_error: 1.3767 - val_loss: 1.8952 - val_regularization_loss: 0.3971 - val_total_loss: 2.2923
# Epoch 60/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.4194 - loss: 2.1271 - regularization_loss: 0.3954 - total_loss: 2.5225 - val_root_mean_squared_error: 1.3644 - val_loss: 1.8615 - val_regularization_loss: 0.3919 - val_total_loss: 2.2534
# Epoch 61/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.4064 - loss: 2.0962 - regularization_loss: 0.3902 - total_loss: 2.4864 - val_root_mean_squared_error: 1.3527 - val_loss: 1.8298 - val_regularization_loss: 0.3868 - val_total_loss: 2.2166
# Epoch 62/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.3939 - loss: 2.0620 - regularization_loss: 0.3851 - total_loss: 2.4471 - val_root_mean_squared_error: 1.3416 - val_loss: 1.7999 - val_regularization_loss: 0.3817 - val_total_loss: 2.1817
# Epoch 63/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.3820 - loss: 1.9767 - regularization_loss: 0.3801 - total_loss: 2.3568 - val_root_mean_squared_error: 1.3311 - val_loss: 1.7718 - val_regularization_loss: 0.3768 - val_total_loss: 2.1486
# Epoch 64/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.3707 - loss: 1.7958 - regularization_loss: 0.3752 - total_loss: 2.1710 - val_root_mean_squared_error: 1.3212 - val_loss: 1.7455 - val_regularization_loss: 0.3720 - val_total_loss: 2.1175
# Epoch 65/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.3598 - loss: 1.8765 - regularization_loss: 0.3704 - total_loss: 2.2469 - val_root_mean_squared_error: 1.3118 - val_loss: 1.7209 - val_regularization_loss: 0.3673 - val_total_loss: 2.0882
# Epoch 66/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.3496 - loss: 1.8228 - regularization_loss: 0.3658 - total_loss: 2.1886 - val_root_mean_squared_error: 1.3031 - val_loss: 1.6979 - val_regularization_loss: 0.3627 - val_total_loss: 2.0606
# Epoch 67/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.3397 - loss: 1.9779 - regularization_loss: 0.3612 - total_loss: 2.3391 - val_root_mean_squared_error: 1.2948 - val_loss: 1.6764 - val_regularization_loss: 0.3582 - val_total_loss: 2.0346
# Epoch 68/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.3305 - loss: 1.9758 - regularization_loss: 0.3567 - total_loss: 2.3325 - val_root_mean_squared_error: 1.2869 - val_loss: 1.6560 - val_regularization_loss: 0.3537 - val_total_loss: 2.0098
# Epoch 69/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.3218 - loss: 1.7725 - regularization_loss: 0.3523 - total_loss: 2.1248 - val_root_mean_squared_error: 1.2795 - val_loss: 1.6370 - val_regularization_loss: 0.3494 - val_total_loss: 1.9864
# Epoch 70/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.3134 - loss: 1.6394 - regularization_loss: 0.3480 - total_loss: 1.9873 - val_root_mean_squared_error: 1.2726 - val_loss: 1.6194 - val_regularization_loss: 0.3451 - val_total_loss: 1.9646
# Epoch 71/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.3053 - loss: 1.8089 - regularization_loss: 0.3437 - total_loss: 2.1526 - val_root_mean_squared_error: 1.2661 - val_loss: 1.6030 - val_regularization_loss: 0.3410 - val_total_loss: 1.9440
# Epoch 72/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2979 - loss: 1.7136 - regularization_loss: 0.3396 - total_loss: 2.0532 - val_root_mean_squared_error: 1.2600 - val_loss: 1.5875 - val_regularization_loss: 0.3369 - val_total_loss: 1.9244
# Epoch 73/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2908 - loss: 1.7061 - regularization_loss: 0.3355 - total_loss: 2.0416 - val_root_mean_squared_error: 1.2542 - val_loss: 1.5730 - val_regularization_loss: 0.3329 - val_total_loss: 1.9059
# Epoch 74/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2840 - loss: 1.6493 - regularization_loss: 0.3316 - total_loss: 1.9808 - val_root_mean_squared_error: 1.2487 - val_loss: 1.5594 - val_regularization_loss: 0.3289 - val_total_loss: 1.8883
# Epoch 75/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2774 - loss: 1.7835 - regularization_loss: 0.3277 - total_loss: 2.1112 - val_root_mean_squared_error: 1.2436 - val_loss: 1.5465 - val_regularization_loss: 0.3251 - val_total_loss: 1.8716
# Epoch 76/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2712 - loss: 1.6694 - regularization_loss: 0.3238 - total_loss: 1.9933 - val_root_mean_squared_error: 1.2387 - val_loss: 1.5345 - val_regularization_loss: 0.3213 - val_total_loss: 1.8558
# Epoch 77/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.2653 - loss: 1.6329 - regularization_loss: 0.3201 - total_loss: 1.9530 - val_root_mean_squared_error: 1.2342 - val_loss: 1.5232 - val_regularization_loss: 0.3176 - val_total_loss: 1.8408
# Epoch 78/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2597 - loss: 1.6286 - regularization_loss: 0.3164 - total_loss: 1.9450 - val_root_mean_squared_error: 1.2299 - val_loss: 1.5127 - val_regularization_loss: 0.3140 - val_total_loss: 1.8267
# Epoch 79/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2543 - loss: 1.6409 - regularization_loss: 0.3128 - total_loss: 1.9537 - val_root_mean_squared_error: 1.2259 - val_loss: 1.5029 - val_regularization_loss: 0.3105 - val_total_loss: 1.8134
# Epoch 80/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2493 - loss: 1.5438 - regularization_loss: 0.3093 - total_loss: 1.8531 - val_root_mean_squared_error: 1.2222 - val_loss: 1.4937 - val_regularization_loss: 0.3070 - val_total_loss: 1.8007
# Epoch 81/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2444 - loss: 1.6290 - regularization_loss: 0.3058 - total_loss: 1.9348 - val_root_mean_squared_error: 1.2187 - val_loss: 1.4852 - val_regularization_loss: 0.3036 - val_total_loss: 1.7888
# Epoch 82/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2398 - loss: 1.6082 - regularization_loss: 0.3025 - total_loss: 1.9107 - val_root_mean_squared_error: 1.2154 - val_loss: 1.4773 - val_regularization_loss: 0.3002 - val_total_loss: 1.7775
# Epoch 83/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2354 - loss: 1.6724 - regularization_loss: 0.2992 - total_loss: 1.9716 - val_root_mean_squared_error: 1.2123 - val_loss: 1.4697 - val_regularization_loss: 0.2970 - val_total_loss: 1.7667
# Epoch 84/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2312 - loss: 1.5687 - regularization_loss: 0.2959 - total_loss: 1.8646 - val_root_mean_squared_error: 1.2094 - val_loss: 1.4626 - val_regularization_loss: 0.2938 - val_total_loss: 1.7564
# Epoch 85/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2272 - loss: 1.5773 - regularization_loss: 0.2927 - total_loss: 1.8700 - val_root_mean_squared_error: 1.2067 - val_loss: 1.4560 - val_regularization_loss: 0.2906 - val_total_loss: 1.7466
# Epoch 86/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2233 - loss: 1.5934 - regularization_loss: 0.2896 - total_loss: 1.8830 - val_root_mean_squared_error: 1.2041 - val_loss: 1.4498 - val_regularization_loss: 0.2875 - val_total_loss: 1.7374
# Epoch 87/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2196 - loss: 1.4857 - regularization_loss: 0.2865 - total_loss: 1.7722 - val_root_mean_squared_error: 1.2017 - val_loss: 1.4440 - val_regularization_loss: 0.2845 - val_total_loss: 1.7285
# Epoch 88/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2160 - loss: 1.4807 - regularization_loss: 0.2835 - total_loss: 1.7642 - val_root_mean_squared_error: 1.1994 - val_loss: 1.4386 - val_regularization_loss: 0.2816 - val_total_loss: 1.7202
# Epoch 89/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2127 - loss: 1.5138 - regularization_loss: 0.2806 - total_loss: 1.7944 - val_root_mean_squared_error: 1.1973 - val_loss: 1.4336 - val_regularization_loss: 0.2787 - val_total_loss: 1.7123
# Epoch 90/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.2094 - loss: 1.5102 - regularization_loss: 0.2777 - total_loss: 1.7879 - val_root_mean_squared_error: 1.1954 - val_loss: 1.4289 - val_regularization_loss: 0.2758 - val_total_loss: 1.7047
# Epoch 91/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.2064 - loss: 1.4666 - regularization_loss: 0.2749 - total_loss: 1.7415 - val_root_mean_squared_error: 1.1935 - val_loss: 1.4245 - val_regularization_loss: 0.2730 - val_total_loss: 1.6976
# Epoch 92/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.2034 - loss: 1.5311 - regularization_loss: 0.2721 - total_loss: 1.8032 - val_root_mean_squared_error: 1.1918 - val_loss: 1.4205 - val_regularization_loss: 0.2703 - val_total_loss: 1.6907
# Epoch 93/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.2006 - loss: 1.4582 - regularization_loss: 0.2694 - total_loss: 1.7276 - val_root_mean_squared_error: 1.1902 - val_loss: 1.4166 - val_regularization_loss: 0.2676 - val_total_loss: 1.6842
# Epoch 94/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1979 - loss: 1.4361 - regularization_loss: 0.2667 - total_loss: 1.7028 - val_root_mean_squared_error: 1.1887 - val_loss: 1.4131 - val_regularization_loss: 0.2650 - val_total_loss: 1.6781
# Epoch 95/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1953 - loss: 1.4707 - regularization_loss: 0.2641 - total_loss: 1.7348 - val_root_mean_squared_error: 1.1874 - val_loss: 1.4099 - val_regularization_loss: 0.2624 - val_total_loss: 1.6722
# Epoch 96/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1928 - loss: 1.4718 - regularization_loss: 0.2615 - total_loss: 1.7334 - val_root_mean_squared_error: 1.1861 - val_loss: 1.4068 - val_regularization_loss: 0.2599 - val_total_loss: 1.6667
# Epoch 97/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1904 - loss: 1.4264 - regularization_loss: 0.2590 - total_loss: 1.6854 - val_root_mean_squared_error: 1.1849 - val_loss: 1.4040 - val_regularization_loss: 0.2574 - val_total_loss: 1.6614
# Epoch 98/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.1881 - loss: 1.3941 - regularization_loss: 0.2566 - total_loss: 1.6507 - val_root_mean_squared_error: 1.1838 - val_loss: 1.4014 - val_regularization_loss: 0.2549 - val_total_loss: 1.6563
# Epoch 99/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1859 - loss: 1.3433 - regularization_loss: 0.2541 - total_loss: 1.5975 - val_root_mean_squared_error: 1.1828 - val_loss: 1.3989 - val_regularization_loss: 0.2526 - val_total_loss: 1.6515
# Epoch 100/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1838 - loss: 1.4413 - regularization_loss: 0.2518 - total_loss: 1.6930 - val_root_mean_squared_error: 1.1818 - val_loss: 1.3967 - val_regularization_loss: 0.2502 - val_total_loss: 1.6469
# Epoch 101/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1817 - loss: 1.4138 - regularization_loss: 0.2495 - total_loss: 1.6633 - val_root_mean_squared_error: 1.1809 - val_loss: 1.3946 - val_regularization_loss: 0.2479 - val_total_loss: 1.6425
# Epoch 102/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1798 - loss: 1.4273 - regularization_loss: 0.2472 - total_loss: 1.6744 - val_root_mean_squared_error: 1.1801 - val_loss: 1.3926 - val_regularization_loss: 0.2457 - val_total_loss: 1.6383
# Epoch 103/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1779 - loss: 1.3682 - regularization_loss: 0.2450 - total_loss: 1.6131 - val_root_mean_squared_error: 1.1793 - val_loss: 1.3908 - val_regularization_loss: 0.2435 - val_total_loss: 1.6343
# Epoch 104/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1760 - loss: 1.3456 - regularization_loss: 0.2428 - total_loss: 1.5884 - val_root_mean_squared_error: 1.1786 - val_loss: 1.3891 - val_regularization_loss: 0.2413 - val_total_loss: 1.6305
# Epoch 105/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1742 - loss: 1.4898 - regularization_loss: 0.2406 - total_loss: 1.7305 - val_root_mean_squared_error: 1.1780 - val_loss: 1.3876 - val_regularization_loss: 0.2392 - val_total_loss: 1.6268
# Epoch 106/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1725 - loss: 1.3375 - regularization_loss: 0.2385 - total_loss: 1.5760 - val_root_mean_squared_error: 1.1773 - val_loss: 1.3861 - val_regularization_loss: 0.2371 - val_total_loss: 1.6233
# Epoch 107/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.1707 - loss: 1.4924 - regularization_loss: 0.2365 - total_loss: 1.7289 - val_root_mean_squared_error: 1.1768 - val_loss: 1.3848 - val_regularization_loss: 0.2351 - val_total_loss: 1.6199
# Epoch 108/500
# 2/2 [==============================] - 0s 19ms/step - root_mean_squared_error: 1.1691 - loss: 1.4627 - regularization_loss: 0.2344 - total_loss: 1.6971 - val_root_mean_squared_error: 1.1762 - val_loss: 1.3835 - val_regularization_loss: 0.2331 - val_total_loss: 1.6166
# Epoch 109/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1675 - loss: 1.3235 - regularization_loss: 0.2324 - total_loss: 1.5559 - val_root_mean_squared_error: 1.1758 - val_loss: 1.3824 - val_regularization_loss: 0.2311 - val_total_loss: 1.6135
# Epoch 110/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.1659 - loss: 1.3295 - regularization_loss: 0.2305 - total_loss: 1.5600 - val_root_mean_squared_error: 1.1753 - val_loss: 1.3813 - val_regularization_loss: 0.2292 - val_total_loss: 1.6105
# Epoch 111/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1643 - loss: 1.4622 - regularization_loss: 0.2285 - total_loss: 1.6907 - val_root_mean_squared_error: 1.1749 - val_loss: 1.3804 - val_regularization_loss: 0.2273 - val_total_loss: 1.6076
# Epoch 112/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.1628 - loss: 1.3945 - regularization_loss: 0.2267 - total_loss: 1.6211 - val_root_mean_squared_error: 1.1745 - val_loss: 1.3794 - val_regularization_loss: 0.2254 - val_total_loss: 1.6049
# Epoch 113/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1614 - loss: 1.3958 - regularization_loss: 0.2248 - total_loss: 1.6207 - val_root_mean_squared_error: 1.1741 - val_loss: 1.3786 - val_regularization_loss: 0.2236 - val_total_loss: 1.6022
# Epoch 114/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1599 - loss: 1.3900 - regularization_loss: 0.2230 - total_loss: 1.6130 - val_root_mean_squared_error: 1.1738 - val_loss: 1.3778 - val_regularization_loss: 0.2218 - val_total_loss: 1.5996
# Epoch 115/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1585 - loss: 1.4176 - regularization_loss: 0.2212 - total_loss: 1.6389 - val_root_mean_squared_error: 1.1735 - val_loss: 1.3771 - val_regularization_loss: 0.2201 - val_total_loss: 1.5971
# Epoch 116/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1571 - loss: 1.4017 - regularization_loss: 0.2195 - total_loss: 1.6211 - val_root_mean_squared_error: 1.1732 - val_loss: 1.3764 - val_regularization_loss: 0.2183 - val_total_loss: 1.5948
# Epoch 117/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1558 - loss: 1.3318 - regularization_loss: 0.2178 - total_loss: 1.5496 - val_root_mean_squared_error: 1.1730 - val_loss: 1.3758 - val_regularization_loss: 0.2166 - val_total_loss: 1.5925
# Epoch 118/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1545 - loss: 1.4552 - regularization_loss: 0.2161 - total_loss: 1.6712 - val_root_mean_squared_error: 1.1727 - val_loss: 1.3753 - val_regularization_loss: 0.2150 - val_total_loss: 1.5903
# Epoch 119/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1532 - loss: 1.3019 - regularization_loss: 0.2144 - total_loss: 1.5163 - val_root_mean_squared_error: 1.1725 - val_loss: 1.3748 - val_regularization_loss: 0.2133 - val_total_loss: 1.5882
# Epoch 120/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1519 - loss: 1.3985 - regularization_loss: 0.2128 - total_loss: 1.6113 - val_root_mean_squared_error: 1.1724 - val_loss: 1.3744 - val_regularization_loss: 0.2117 - val_total_loss: 1.5862
# Epoch 121/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1507 - loss: 1.2797 - regularization_loss: 0.2112 - total_loss: 1.4909 - val_root_mean_squared_error: 1.1722 - val_loss: 1.3741 - val_regularization_loss: 0.2101 - val_total_loss: 1.5842
# Epoch 122/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1494 - loss: 1.3390 - regularization_loss: 0.2096 - total_loss: 1.5486 - val_root_mean_squared_error: 1.1721 - val_loss: 1.3737 - val_regularization_loss: 0.2086 - val_total_loss: 1.5823
# Epoch 123/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1482 - loss: 1.3422 - regularization_loss: 0.2081 - total_loss: 1.5502 - val_root_mean_squared_error: 1.1719 - val_loss: 1.3734 - val_regularization_loss: 0.2071 - val_total_loss: 1.5805
# Epoch 124/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1471 - loss: 1.3529 - regularization_loss: 0.2066 - total_loss: 1.5595 - val_root_mean_squared_error: 1.1718 - val_loss: 1.3732 - val_regularization_loss: 0.2056 - val_total_loss: 1.5788
# Epoch 125/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1459 - loss: 1.3864 - regularization_loss: 0.2051 - total_loss: 1.5916 - val_root_mean_squared_error: 1.1717 - val_loss: 1.3730 - val_regularization_loss: 0.2041 - val_total_loss: 1.5771
# Epoch 126/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1447 - loss: 1.3266 - regularization_loss: 0.2037 - total_loss: 1.5302 - val_root_mean_squared_error: 1.1717 - val_loss: 1.3728 - val_regularization_loss: 0.2027 - val_total_loss: 1.5755
# Epoch 127/500
# 2/2 [==============================] - 0s 21ms/step - root_mean_squared_error: 1.1436 - loss: 1.4047 - regularization_loss: 0.2022 - total_loss: 1.6070 - val_root_mean_squared_error: 1.1716 - val_loss: 1.3726 - val_regularization_loss: 0.2013 - val_total_loss: 1.5739
# Epoch 128/500
# 2/2 [==============================] - 0s 20ms/step - root_mean_squared_error: 1.1425 - loss: 1.4114 - regularization_loss: 0.2008 - total_loss: 1.6123 - val_root_mean_squared_error: 1.1715 - val_loss: 1.3725 - val_regularization_loss: 0.1999 - val_total_loss: 1.5724
# Epoch 129/500
# 2/2 [==============================] - 0s 22ms/step - root_mean_squared_error: 1.1414 - loss: 1.3598 - regularization_loss: 0.1994 - total_loss: 1.5592 - val_root_mean_squared_error: 1.1715 - val_loss: 1.3724 - val_regularization_loss: 0.1985 - val_total_loss: 1.5709
# Epoch 130/500
# 2/2 [==============================] - 0s 23ms/step - root_mean_squared_error: 1.1402 - loss: 1.4592 - regularization_loss: 0.1981 - total_loss: 1.6573 - val_root_mean_squared_error: 1.1714 - val_loss: 1.3723 - val_regularization_loss: 0.1972 - val_total_loss: 1.5694

# %%
test_metrics = model.evaluate(test_data, return_dict=True)
print(f"Test RMSE: {test_metrics['root_mean_squared_error']}")

predictions = []
actual_ratings = []
for batch in test_data:
    predicted_ratings = model(batch).numpy()
    actual_ratings.extend(batch["rating"].numpy())
    predictions.extend(predicted_ratings)

predictions = np.array(predictions)
actual_ratings = np.array(actual_ratings)

rmse = np.sqrt(np.mean((predictions - actual_ratings) ** 2))
print(f"RECHECK RMSE: {rmse}")

if np.all(actual_ratings == actual_ratings.round()):
    correct = np.mean(predictions.round() == actual_ratings)
    print(f"Rounded Accuracy: {correct}")
else:
    print("Actual ratings are not integers, skipping rounded accuracy calculation.")
# Out:
# 1/1 [==============================] - 0s 17ms/step - root_mean_squared_error: 1.1812 - loss: 1.3952 - regularization_loss: 0.1502 - total_loss: 1.5454
# Test RMSE: 1.1811875104904175
# RECHECK RMSE: 1.1811874576036936
# Rounded Accuracy: 0.31844029244516653

# %% [markdown]
# ## Downstream Application

# %%
from recommendation import Recommendation

# %%
recommender = Recommendation(model, cleaned_df)

# %%
recommender.recommend(gmap_id)
# Out:
#       reviewer_id  pred_rating
# 34   1.032565e+20     4.925717
# 259  1.142927e+20     4.905312
# 199  1.105121e+20     4.876152
# 160  1.089448e+20     4.875777
# 187  1.097880e+20     4.874481
# 33   1.032367e+20     4.867342
# 59   1.053813e+20     4.854186
# 305  1.180579e+20     4.845252
# 227  1.124081e+20     4.843285
# 142  1.088001e+20     4.834175
# 166  1.089697e+20     4.833995
# 177  1.091675e+20     4.832286
# 189  1.098933e+20     4.830398
# 29   1.029131e+20     4.825627
# 205  1.108769e+20     4.822819
# 60   1.054046e+20     4.818396
# 184  1.096526e+20     4.813556
# 173  1.090240e+20     4.813520
# 228  1.124606e+20     4.812196
# 171  1.089897e+20     4.811954
