# %% [markdown]
# # Running Models

# %%
# %load_ext autoreload
# %autoreload 2

import gzip
from collections import defaultdict
import math
import numpy as np
import string
import random
import string
from pathlib import Path

import tensorflow as tf
import tensorflow_recommenders as tfrs
import pandas as pd
import keras_tuner as kt

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ***
# # Description
# ***
#
# ## Latent Factor Models + Neural Corrolative Filteration
#
# $$
# \arg \min_{\alpha, \beta, \gamma} \sum_{u,i} \left( \alpha + \beta_u + \beta_i + \gamma_u \cdot \gamma_i - R_{u,i} \right)^2 + \lambda \left[ \sum_u \beta_u^2 + \sum_i \beta_i^2 + \sum_i \left\| \gamma_i \right\|_2^2 + \sum_u \left\| \gamma_u \right\|_2^2 \right]
# $$
#
# Single terms:
# - **Global bias, $ \alpha $**: the overall average rating across all users and items.
# - **User bias, $ \beta_u $**: captures the tendency of user $ u $ to rate items higher or lower than the global average.
# - **Item bias, $ \beta_i $**: inherent popularity or quality of item $ i $.
# - **User and item latent factors, $ \gamma_u $ and $ \gamma_i $**: capture the latent preferences of user $ u $ and the latent characteristics of item $ i $, respectively.
#
# Combinations of terms:
# - **Prediction error**: The expression $ \left( \alpha + \beta_u + \beta_i + \gamma_u \cdot \gamma_i - R_{u,i} \right)^2 $ measures the squared difference between the predicted rating $ (\alpha + \beta_u + \beta_i + \gamma_u \cdot \gamma_i) $ and the actual rating $ R_{u,i} $ for user $ u $ and item $ i $.
# - **Regularization term**: The term $ \lambda \left[ \sum_u \beta_u^2 + \sum_i \beta_i^2 + \sum_i \left\| \gamma_i \right\|_2^2 + \sum_u \left\| \gamma_u \right\|_2^2 \right] $ penalizes large values of the biases and latent factors to prevent overfitting. Here:
#   - $ \sum_u \beta_u^2 $ and $ \sum_i \beta_i^2 $ apply regularization to the user and item biases, respectively.
#   - $ \sum_i \left\| \gamma_i \right\|_2^2 $ and $ \sum_u \left\| \gamma_u \right\|_2^2 $ apply regularization to the latent factors of items and users, respectively.
# - **Regularization coefficient, $ \lambda $**: This parameter controls the strength of the regularization, balancing the fit to the data with the complexity of the model.

# %%
from latent_factor import LatentFactorModel

# %%
base_path = Path.cwd().parent.parent
meta_file_path = base_path / "data" / "california_clean_metadata.json.gz"
data_path = base_path / "data" / "california_clean_data.json.gz"

meta_df = pd.read_json(meta_file_path, compression = 'gzip', lines = True)
df = pd.read_json(data_path, compression = 'gzip', lines = True)
df = df.reset_index()

merged_df = df.merge(meta_df, on='gmap_id', how='inner')
columns_to_remove = [col for col in df.columns if col.endswith('_y')]
merged_clean = df.drop(columns=columns_to_remove)

merged_clean["gmap_id"] = merged_clean["gmap_id"].astype(str)
merged_clean["reviewer_id"] = merged_clean["reviewer_id"].astype(str)
data_query = merged_clean[['gmap_id', 'reviewer_id', 'rating']]

merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158336 entries, 0 to 1158335
# Data columns (total 21 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   index              1158336 non-null  int64
#  1   reviewer_id        1158336 non-null  object
#  2   reviewer_name      1158336 non-null  object
#  3   review_time(unix)  1158336 non-null  int64
#  4   rating             1158336 non-null  int64
#  5   text               650897 non-null   object
#  6   resp               73022 non-null    object
#  7   gmap_id            1158336 non-null  object
#  8   has_rep            1158336 non-null  bool
#  9   gmap_name          1158336 non-null  object
#  10  address            1158336 non-null  object
#  11  latitude           1158336 non-null  float64
#  12  longitude          1158336 non-null  float64
#  13  description        838359 non-null   object
#  14  category           1158336 non-null  object
#  15  avg_rating         1158336 non-null  float64
#  16  num_of_reviews     1158336 non-null  int64
#  17  price              591411 non-null   object
#  18  hours              1065012 non-null  object
#  19  MISC               1131206 non-null  object
#  20  relative_results   1158336 non-null  object
# dtypes: bool(1), float64(3), int64(4), object(13)
# memory usage: 177.9+ MB

# %%
train_df = merged_clean.sample(frac=0.8, random_state=42)
test_df = merged_clean.drop(train_df.index)

def df_to_tf_dataset(dataframe):
    return tf.data.Dataset.from_tensor_slices({
        "gmap_id": dataframe["gmap_id"].values,
        "reviewer_id": dataframe["reviewer_id"].values,
        "rating": dataframe["rating"].values
    })

train_data = df_to_tf_dataset(train_df).shuffle(1024).batch(4096)
test_data = df_to_tf_dataset(test_df).batch(4096)

# %%
embedding_dim = 32
dense_units = 32
l2_reg = 0.0201
model = LatentFactorModel(l2_reg, dense_units, embedding_dim, data_query)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_root_mean_squared_error", 
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-4, 
    decay_steps=10000, 
    decay_rate=0.9
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule))
model.fit(train_data, epochs=200, validation_data=test_data, callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/200
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 227/227 [==============================] - 4s 12ms/step - root_mean_squared_error: 4.2420 - loss: 17.9738 - regularization_loss: 21.0357 - total_loss: 39.0095 - val_root_mean_squared_error: 3.8885 - val_loss: 14.7711 - val_regularization_loss: 9.2003 - val_total_loss: 23.9715
# Epoch 2/200
# 227/227 [==============================] - 3s 12ms/step - root_mean_squared_error: 3.3047 - loss: 10.8876 - regularization_loss: 4.7091 - total_loss: 15.5966 - val_root_mean_squared_error: 2.5532 - val_loss: 5.8009 - val_regularization_loss: 2.0271 - val_total_loss: 7.8280
# Epoch 3/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 1.8887 - loss: 3.5525 - regularization_loss: 1.1299 - total_loss: 4.6824 - val_root_mean_squared_error: 1.2835 - val_loss: 1.2320 - val_regularization_loss: 0.5675 - val_total_loss: 1.7994
# Epoch 4/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 1.0713 - loss: 1.1455 - regularization_loss: 0.3156 - total_loss: 1.4611 - val_root_mean_squared_error: 0.9585 - val_loss: 0.7615 - val_regularization_loss: 0.1469 - val_total_loss: 0.9084
# Epoch 5/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.9324 - loss: 0.8688 - regularization_loss: 0.0824 - total_loss: 0.9513 - val_root_mean_squared_error: 0.9207 - val_loss: 0.7319 - val_regularization_loss: 0.0440 - val_total_loss: 0.7759
# Epoch 6/200
# 227/227 [==============================] - 3s 12ms/step - root_mean_squared_error: 0.9141 - loss: 0.8353 - regularization_loss: 0.0313 - total_loss: 0.8666 - val_root_mean_squared_error: 0.9136 - val_loss: 0.7249 - val_regularization_loss: 0.0237 - val_total_loss: 0.7486
# Epoch 7/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.9098 - loss: 0.8275 - regularization_loss: 0.0212 - total_loss: 0.8487 - val_root_mean_squared_error: 0.9114 - val_loss: 0.7222 - val_regularization_loss: 0.0195 - val_total_loss: 0.7417
# Epoch 8/200
# 227/227 [==============================] - 3s 12ms/step - root_mean_squared_error: 0.9079 - loss: 0.8242 - regularization_loss: 0.0189 - total_loss: 0.8431 - val_root_mean_squared_error: 0.9100 - val_loss: 0.7202 - val_regularization_loss: 0.0184 - val_total_loss: 0.7386
# Epoch 9/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.9064 - loss: 0.8212 - regularization_loss: 0.0182 - total_loss: 0.8395 - val_root_mean_squared_error: 0.9087 - val_loss: 0.7183 - val_regularization_loss: 0.0180 - val_total_loss: 0.7363
# Epoch 10/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.9049 - loss: 0.8181 - regularization_loss: 0.0180 - total_loss: 0.8361 - val_root_mean_squared_error: 0.9074 - val_loss: 0.7164 - val_regularization_loss: 0.0178 - val_total_loss: 0.7342
# Epoch 11/200
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.9033 - loss: 0.8154 - regularization_loss: 0.0179 - total_loss: 0.8333 - val_root_mean_squared_error: 0.9059 - val_loss: 0.7143 - val_regularization_loss: 0.0177 - val_total_loss: 0.7320
# Epoch 12/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.9016 - loss: 0.8128 - regularization_loss: 0.0178 - total_loss: 0.8306 - val_root_mean_squared_error: 0.9044 - val_loss: 0.7122 - val_regularization_loss: 0.0177 - val_total_loss: 0.7298
# Epoch 13/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8998 - loss: 0.8101 - regularization_loss: 0.0178 - total_loss: 0.8279 - val_root_mean_squared_error: 0.9029 - val_loss: 0.7100 - val_regularization_loss: 0.0176 - val_total_loss: 0.7276
# Epoch 14/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8980 - loss: 0.8060 - regularization_loss: 0.0177 - total_loss: 0.8237 - val_root_mean_squared_error: 0.9012 - val_loss: 0.7076 - val_regularization_loss: 0.0176 - val_total_loss: 0.7252
# Epoch 15/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8961 - loss: 0.8033 - regularization_loss: 0.0177 - total_loss: 0.8210 - val_root_mean_squared_error: 0.8996 - val_loss: 0.7053 - val_regularization_loss: 0.0175 - val_total_loss: 0.7228
# Epoch 16/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8942 - loss: 0.7994 - regularization_loss: 0.0177 - total_loss: 0.8171 - val_root_mean_squared_error: 0.8979 - val_loss: 0.7028 - val_regularization_loss: 0.0175 - val_total_loss: 0.7203
# Epoch 17/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8922 - loss: 0.7959 - regularization_loss: 0.0176 - total_loss: 0.8135 - val_root_mean_squared_error: 0.8962 - val_loss: 0.7004 - val_regularization_loss: 0.0175 - val_total_loss: 0.7179
# Epoch 18/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8902 - loss: 0.7922 - regularization_loss: 0.0176 - total_loss: 0.8098 - val_root_mean_squared_error: 0.8944 - val_loss: 0.6979 - val_regularization_loss: 0.0174 - val_total_loss: 0.7154
# Epoch 19/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8882 - loss: 0.7883 - regularization_loss: 0.0175 - total_loss: 0.8059 - val_root_mean_squared_error: 0.8927 - val_loss: 0.6954 - val_regularization_loss: 0.0174 - val_total_loss: 0.7128
# Epoch 20/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8861 - loss: 0.7848 - regularization_loss: 0.0175 - total_loss: 0.8023 - val_root_mean_squared_error: 0.8909 - val_loss: 0.6928 - val_regularization_loss: 0.0174 - val_total_loss: 0.7102
# Epoch 21/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8841 - loss: 0.7809 - regularization_loss: 0.0175 - total_loss: 0.7983 - val_root_mean_squared_error: 0.8891 - val_loss: 0.6903 - val_regularization_loss: 0.0173 - val_total_loss: 0.7076
# Epoch 22/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8820 - loss: 0.7779 - regularization_loss: 0.0174 - total_loss: 0.7954 - val_root_mean_squared_error: 0.8873 - val_loss: 0.6877 - val_regularization_loss: 0.0173 - val_total_loss: 0.7050
# Epoch 23/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8799 - loss: 0.7740 - regularization_loss: 0.0174 - total_loss: 0.7914 - val_root_mean_squared_error: 0.8856 - val_loss: 0.6852 - val_regularization_loss: 0.0172 - val_total_loss: 0.7025
# Epoch 24/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8779 - loss: 0.7705 - regularization_loss: 0.0174 - total_loss: 0.7879 - val_root_mean_squared_error: 0.8838 - val_loss: 0.6827 - val_regularization_loss: 0.0172 - val_total_loss: 0.6999
# Epoch 25/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8758 - loss: 0.7668 - regularization_loss: 0.0174 - total_loss: 0.7842 - val_root_mean_squared_error: 0.8820 - val_loss: 0.6802 - val_regularization_loss: 0.0172 - val_total_loss: 0.6974
# Epoch 26/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8738 - loss: 0.7635 - regularization_loss: 0.0173 - total_loss: 0.7808 - val_root_mean_squared_error: 0.8803 - val_loss: 0.6777 - val_regularization_loss: 0.0172 - val_total_loss: 0.6948
# Epoch 27/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8718 - loss: 0.7596 - regularization_loss: 0.0173 - total_loss: 0.7770 - val_root_mean_squared_error: 0.8786 - val_loss: 0.6752 - val_regularization_loss: 0.0172 - val_total_loss: 0.6924
# Epoch 28/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8697 - loss: 0.7563 - regularization_loss: 0.0174 - total_loss: 0.7737 - val_root_mean_squared_error: 0.8768 - val_loss: 0.6727 - val_regularization_loss: 0.0172 - val_total_loss: 0.6899
# Epoch 29/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8677 - loss: 0.7521 - regularization_loss: 0.0174 - total_loss: 0.7695 - val_root_mean_squared_error: 0.8751 - val_loss: 0.6702 - val_regularization_loss: 0.0173 - val_total_loss: 0.6875
# Epoch 30/200
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8657 - loss: 0.7490 - regularization_loss: 0.0174 - total_loss: 0.7664 - val_root_mean_squared_error: 0.8734 - val_loss: 0.6678 - val_regularization_loss: 0.0173 - val_total_loss: 0.6851
# Epoch 31/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8637 - loss: 0.7458 - regularization_loss: 0.0175 - total_loss: 0.7633 - val_root_mean_squared_error: 0.8717 - val_loss: 0.6654 - val_regularization_loss: 0.0174 - val_total_loss: 0.6828
# Epoch 32/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8618 - loss: 0.7422 - regularization_loss: 0.0176 - total_loss: 0.7598 - val_root_mean_squared_error: 0.8701 - val_loss: 0.6629 - val_regularization_loss: 0.0175 - val_total_loss: 0.6804
# Epoch 33/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.8598 - loss: 0.7395 - regularization_loss: 0.0177 - total_loss: 0.7572 - val_root_mean_squared_error: 0.8684 - val_loss: 0.6605 - val_regularization_loss: 0.0177 - val_total_loss: 0.6781
# Epoch 34/200
# 227/227 [==============================] - 3s 12ms/step - root_mean_squared_error: 0.8579 - loss: 0.7353 - regularization_loss: 0.0179 - total_loss: 0.7531 - val_root_mean_squared_error: 0.8667 - val_loss: 0.6580 - val_regularization_loss: 0.0178 - val_total_loss: 0.6759
# Epoch 35/200
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8559 - loss: 0.7316 - regularization_loss: 0.0181 - total_loss: 0.7497 - val_root_mean_squared_error: 0.8650 - val_loss: 0.6556 - val_regularization_loss: 0.0180 - val_total_loss: 0.6737
# Epoch 36/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.
200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.7772 - loss: 0.6040 - regularization_loss: 0.0248 - total_loss: 0.6288 - val_root_mean_squared_error: 0.8050 - val_loss: 0.5624 - val_regularization_loss: 0.0246 - val_total_loss: 0.5871
# Epoch 107/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.7769 - loss: 0.6033 - regularization_loss: 0.0246 - total_loss: 0.6279 - val_root_mean_squared_error: 0.8049 - val_loss: 0.5626 - val_regularization_loss: 0.0244 - val_total_loss: 0.5870
# Epoch 108/200
# 227/227 [==============================] - 3s 12ms/step - root_mean_squared_error: 0.7767 - loss: 0.6027 - regularization_loss: 0.0244 - total_loss: 0.6271 - val_root_mean_squared_error: 0.8049 - val_loss: 0.5622 - val_regularization_loss: 0.0242 - val_total_loss: 0.5864
# Epoch 109/200
# 227/227 [==============================] - 3s 12ms/step - root_mean_squared_error: 0.7764 - loss: 0.6022 - regularization_loss: 0.0241 - total_loss: 0.6263 - val_root_mean_squared_error: 0.8048 - val_loss: 0.5623 - val_regularization_loss: 0.0240 - val_total_loss: 0.5863
# Epoch 110/200
# 227/227 [==============================] - 3s 13ms/step - root_mean_squared_error: 0.7761 - loss: 0.6020 - regularization_loss: 0.0239 - total_loss: 0.6260 - val_root_mean_squared_error: 0.8048 - val_loss: 0.5623 - val_regularization_loss: 0.0237 - val_total_loss: 0.5860

# %% [markdown]
# Evaluation

# %%
test_metrics = model.evaluate(test_data, return_dict=True)
print(f"Test RMSE: {test_metrics['root_mean_squared_error']}")

predictions = []
actual_ratings = []
for batch in test_data:
    predicted_ratings = model(batch).numpy()
    actual_ratings.extend(batch["rating"].numpy())
    predictions.extend(predicted_ratings)

predictions = np.array(predictions)
actual_ratings = np.array(actual_ratings)

rmse = np.sqrt(np.mean((predictions - actual_ratings) ** 2))
print(f"RECHECK RMSE: {rmse}")

if np.all(actual_ratings == actual_ratings.round()):
    correct = np.mean(predictions.round() == actual_ratings)
    print(f"Rounded Accuracy: {correct}")
else:
    print("Actual ratings are not integers, skipping rounded accuracy calculation.")
# Out:
# 57/57 [==============================] - 0s 5ms/step - root_mean_squared_error: 0.8054 - loss: 0.6465 - regularization_loss: 0.0261 - total_loss: 0.6725
# Test RMSE: 0.8053553700447083
# RECHECK RMSE: 0.8053553808884151
# Rounded Accuracy: 0.5641847997341011

# %% [markdown]
# ***
# # Description
# ***
#
# ## Temporal Latent Factor Model + Neural Corrolative (Static Latent)
# **Notice that item $i$ refers to the business and user $u$ refers to the user.**
#
# $$
# \hat{r}_{u,i,t} = \mu + \beta_i + \beta_i(t) + \beta_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_u, \gamma_i)
# $$
#
# $$
# \beta_i(t) = \beta_i + \beta_{i,\text{bin}}(t) + \beta_{i,\text{period}}(t)
# $$
#
#
# **Static User/Item Bias**:
# - Static bias for item $ i $:
#   $$
#   \beta_i = \text{Embedding}(\text{gmap\_id})
#   $$
# - Static bias for user $ u $:
#   $$
#   \beta_u = \text{Embedding}(\text{reviewer\_id})
#   $$
#
#
# **Temporal User/Item Bias**:
# - Temporal bias for item $ i $ based on time bins:
#   $$
#   \beta_i(t) = \text{Embedding}(\text{time\_bin})
#   $$
# - Temporal deviation for user $ u $:
#   $$
#   \text{dev}_u(t) = \text{sgn}(t - \bar{t}_u) \cdot |t - \bar{t}_u|^{0.4}
#   $$
#   - $ t $: Timestamp of the rating.
#   - $ \bar{t}_u $: Mean timestamp of user $ u $'s ratings.
#   - $ \text{sgn}(x) $: Sign function, returning $ -1 $ if $ x < 0 $, and $ 1 $ otherwise.
# - Scaled user deviation:
#   $$
#   \alpha_u \cdot \text{dev}_u(t)
#   $$
#   - $ \alpha_u $: Trainable scaling factor for user $ u $.
#
# **Latent Interaction**:
# - User embedding:
#   $$
#   \gamma_u = \text{Embedding}(\text{reviewer\_id})
#   $$
# - Item embedding:
#   $$
#   \gamma_i = \text{Embedding}(\text{gmap\_id})
#   $$
# - Interaction between user and item embeddings is the following where $ \text{NN} $ is a dense neural network:
#   $$
#   f(\gamma_u, \gamma_i) = \text{NN}([\gamma_u, \gamma_i])
#   $$
#
# **Final Prediction**
# $$
# \hat{r}_{u,i,t} = \mu + b_i + b_i(t) + b_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_u, \gamma_i)
# $$
#
# **Loss Function**:
# $$
# \mathcal{L} = \frac{1}{N} \sum_{(u, i, t) \in \text{Train}} \left( r_{u,i,t} - \hat{r}_{u,i,t} \right)^2
# $$
#
# **Optimization**:
#
# $$
# \arg \min_{\alpha, \beta, \gamma} \sum_{u,i} \left(\mu + b_i + b_i(t) + b_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_u, \gamma_i) - R_{u,i} \right)^2 + \lambda \left[ \sum_u \beta_u^2 + \sum_i \beta_i^2 + \sum_i \left\| \gamma_i \right\|_2^2 + \sum_u \left\| \gamma_u \right\|_2^2 \right]
# $$

# %%
from temporal_static import TemporalStaticModel
data_query = merged_clean

# %% [markdown]
# Preparation and normalization (key)

# %%
# Weekly bins for item bias
data_query["time_bin"] = data_query["review_time(unix)"] // (7 * 24 * 3600) # same week in same bin

# Mean timestamp for user bias
user_mean_times = data_query.groupby("reviewer_id")["review_time(unix)"].mean()
data_query["user_mean_time"] = data_query["reviewer_id"].map(user_mean_times)

train_df = data_query.sample(frac=0.8, random_state=42)
test_df = data_query.drop(train_df.index)

# Calculate mean and std for normalization
time_mean, time_std = train_df["review_time(unix)"].mean(), train_df["review_time(unix)"].std()
user_mean_time_mean, user_mean_time_std = train_df["user_mean_time"].mean(), train_df["user_mean_time"].std()

# Normalize the training and test data
train_df["review_time(unix)"] = (train_df["review_time(unix)"] - time_mean) / time_std
test_df["review_time(unix)"] = (test_df["review_time(unix)"] - time_mean) / time_std
train_df["user_mean_time"] = (train_df["user_mean_time"] - user_mean_time_mean) / user_mean_time_std
test_df["user_mean_time"] = (test_df["user_mean_time"] - user_mean_time_mean) / user_mean_time_std

# %% [markdown]
# Put in TF format

# %%
# Function to convert DataFrame to TensorFlow dataset
def df_to_tf_dataset(dataframe):
    return tf.data.Dataset.from_tensor_slices({
        "reviewer_id": dataframe["reviewer_id"].astype(str),
        "gmap_id": dataframe["gmap_id"].astype(str),
        "time": dataframe["review_time(unix)"].astype(float),
        "time_bin": dataframe["time_bin"].astype(float),
        "user_mean_time": dataframe["user_mean_time"],
        "rating": dataframe["rating"]
    })

# Create TensorFlow datasets
train_data = df_to_tf_dataset(train_df).shuffle(1024).batch(4096)
test_data = df_to_tf_dataset(test_df).batch(4096)

train_df[["reviewer_id", "gmap_id", "review_time(unix)", "time_bin", "user_mean_time", "rating"]].sample(6)
# Out:
#                    reviewer_id                                gmap_id  \
# 196909  1.0916236319999998e+20  0x7954c9dceb584fe7:0x78519543b84f347f
# 790084         1.090580207e+20  0x7c00688823ee72fb:0x40d02d372515187e
# 13726          1.181338133e+20  0x7c006df045a36271:0x821f7e897cfe859f
# 6863    1.0164254180000001e+20  0x79524b7280778479:0x60eed0aa0e92f995
# 974016         1.149971521e+20  0x7c00660d84ab0d0b:0x1ae443215ed5b146
# 557289         1.031438527e+20   0x7c0065ffde090f89:0xc2eb0075cafc16d
#
#         review_time(unix)  time_bin  user_mean_time  rating
# 196909           0.891973   2616794        0.715646       5
# 790084          -0.017285   2559611       -0.020666       5
# 13726            1.195468   2635880        0.942700       5
# 6863            -0.483220   2530309       -0.100013       5
# 974016           0.291537   2579033        0.089732       5
# 557289          -0.467079   2531324       -0.633080       3

# %%
embedding_dim = 32
dense_units = 32
l2_reg = 0.0201
time_bins= 10
model = TemporalStaticModel(l2_reg, dense_units, embedding_dim, data_query, time_bins)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_root_mean_squared_error", 
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3, 
    decay_steps=1000, 
    decay_rate=0.8
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule))
model.fit(train_data, epochs=500, validation_data=test_data, callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 227/227 [==============================] - 4s 15ms/step - root_mean_squared_error: 1.1156 - loss: 1.2421 - regularization_loss: 21.1187 - total_loss: 22.3608 - val_root_mean_squared_error: 0.9623 - val_loss: 0.7997 - val_regularization_loss: 9.3681 - val_total_loss: 10.1678
# Epoch 2/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.9314 - loss: 0.8673 - regularization_loss: 4.7631 - total_loss: 5.6304 - val_root_mean_squared_error: 0.9257 - val_loss: 0.7367 - val_regularization_loss: 1.9108 - val_total_loss: 2.6475
# Epoch 3/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.9211 - loss: 0.8478 - regularization_loss: 0.9076 - total_loss: 1.7554 - val_root_mean_squared_error: 0.9221 - val_loss: 0.7329 - val_regularization_loss: 0.3233 - val_total_loss: 1.0562
# Epoch 4/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.9174 - loss: 0.8415 - regularization_loss: 0.1456 - total_loss: 0.9871 - val_root_mean_squared_error: 0.9191 - val_loss: 0.7295 - val_regularization_loss: 0.0491 - val_total_loss: 0.7786
# Epoch 5/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.9142 - loss: 0.8354 - regularization_loss: 0.0242 - total_loss: 0.8596 - val_root_mean_squared_error: 0.9165 - val_loss: 0.7264 - val_regularization_loss: 0.0116 - val_total_loss: 0.7380
# Epoch 6/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.9113 - loss: 0.8305 - regularization_loss: 0.0090 - total_loss: 0.8395 - val_root_mean_squared_error: 0.9141 - val_loss: 0.7233 - val_regularization_loss: 0.0077 - val_total_loss: 0.7311
# Epoch 7/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.
500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8137 - loss: 0.6623 - regularization_loss: 0.0361 - total_loss: 0.6984 - val_root_mean_squared_error: 0.8359 - val_loss: 0.6160 - val_regularization_loss: 0.0361 - val_total_loss: 0.6521
# Epoch 79/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8135 - loss: 0.6613 - regularization_loss: 0.0361 - total_loss: 0.6975 - val_root_mean_squared_error: 0.8358 - val_loss: 0.6158 - val_regularization_loss: 0.0361 - val_total_loss: 0.6520
# Epoch 80/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8132 - loss: 0.6609 - regularization_loss: 0.0362 - total_loss: 0.6971 - val_root_mean_squared_error: 0.8356 - val_loss: 0.6156 - val_regularization_loss: 0.0362 - val_total_loss: 0.6518
# Epoch 81/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8130 - loss: 0.6606 - regularization_loss: 0.0362 - total_loss: 0.6968 - val_root_mean_squared_error: 0.8355 - val_loss: 0.6154 - val_regularization_loss: 0.0362 - val_total_loss: 0.6517
# Epoch 82/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8129 - loss: 0.6604 - regularization_loss: 0.0363 - total_loss: 0.6967 - val_root_mean_squared_error: 0.8354 - val_loss: 0.6153 - val_regularization_loss: 0.0363 - val_total_loss: 0.6515
# Epoch 83/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8127 - loss: 0.6601 - regularization_loss: 0.0363 - total_loss: 0.6964 - val_root_mean_squared_error: 0.8353 - val_loss: 0.6151 - val_regularization_loss: 0.0363 - val_total_loss: 0.6514
# Epoch 84/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8125 - loss: 0.6596 - regularization_loss: 0.0363 - total_loss: 0.6960 - val_root_mean_squared_error: 0.8352 - val_loss: 0.6149 - val_regularization_loss: 0.0364 - val_total_loss: 0.6513
# Epoch 85/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8124 - loss: 0.6593 - regularization_loss: 0.0364 - total_loss: 0.6957 - val_root_mean_squared_error: 0.8351 - val_loss: 0.6148 - val_regularization_loss: 0.0364 - val_total_loss: 0.6512
# Epoch 86/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8122 - loss: 0.6589 - regularization_loss: 0.0364 - total_loss: 0.6953 - val_root_mean_squared_error: 0.8350 - val_loss: 0.6146 - val_regularization_loss: 0.0364 - val_total_loss: 0.6510
# Epoch 87/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8121 - loss: 0.6590 - regularization_loss: 0.0364 - total_loss: 0.6954 - val_root_mean_squared_error: 0.8349 - val_loss: 0.6145 - val_regularization_loss: 0.0365 - val_total_loss: 0.6509
# Epoch 88/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8119 - loss: 0.6587 - regularization_loss: 0.0365 - total_loss: 0.6951 - val_root_mean_squared_error: 0.8348 - val_loss: 0.6143 - val_regularization_loss: 0.0365 - val_total_loss: 0.6508
# Epoch 89/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8118 - loss: 0.6589 - regularization_loss: 0.0365 - total_loss: 0.6954 - val_root_mean_squared_error: 0.8347 - val_loss: 0.6142 - val_regularization_loss: 0.0365 - val_total_loss: 0.6507
# Epoch 90/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8117 - loss: 0.6589 - regularization_loss: 0.0365 - total_loss: 0.6955 - val_root_mean_squared_error: 0.8347 - val_loss: 0.6141 - val_regularization_loss: 0.0365 - val_total_loss: 0.6506
# Epoch 91/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8115 - loss: 0.6580 - regularization_loss: 0.0366 - total_loss: 0.6945 - val_root_mean_squared_error: 0.8346 - val_loss: 0.6140 - val_regularization_loss: 0.0366 - val_total_loss: 0.6505
# Epoch 92/500
# 227/227 [==============================] - 3s 14ms/step - root_mean_squared_error: 0.8114 - loss: 0.6579 - regularization_loss: 0.0366 - total_loss: 0.6945 - val_root_mean_squared_error: 0.8345 - val_loss: 0.6139 - val_regularization_loss: 0.0366 - val_total_loss: 0.6505
# Epoch 93/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8113 - loss: 0.6581 - regularization_loss: 0.0366 - total_loss: 0.6948 - val_root_mean_squared_error: 0.8344 - val_loss: 0.6138 - val_regularization_loss: 0.0366 - val_total_loss: 0.6504

# %%
test_metrics = model.evaluate(test_data, return_dict=True)
print(f"Test RMSE: {test_metrics['root_mean_squared_error']}")

predictions = []
actual_ratings = []
for batch in test_data:
    predicted_ratings = model(batch).numpy()
    actual_ratings.extend(batch["rating"].numpy())
    predictions.extend(predicted_ratings)

predictions = np.array(predictions)
actual_ratings = np.array(actual_ratings)

rmse = np.sqrt(np.mean((predictions - actual_ratings) ** 2))
print(f"RECHECK RMSE: {rmse}")

if np.all(actual_ratings == actual_ratings.round()):
    correct = np.mean(predictions.round() == actual_ratings)
    print(f"Rounded Accuracy: {correct}")
else:
    print("Actual ratings are not integers, skipping rounded accuracy calculation.")
# Out:
# 57/57 [==============================] - 0s 8ms/step - root_mean_squared_error: 0.8353 - loss: 0.6957 - regularization_loss: 0.0363 - total_loss: 0.7320
# Test RMSE: 0.8352956175804138
# RECHECK RMSE: 0.8338168255728705
# Rounded Accuracy: 0.5068093427203701

# %% [markdown]
# ***
# # Description
# ***
#
# ## Temporal Latent Factor Model + Neural Corrolative (Dynamic Latent)
# **Notice that item $i$ refers to the business and user $u$ refers to the user.**
#
# **Modification**:
#
# $$
# \gamma_{u,k}(t) = \gamma_{u,k} + \alpha_{u,k} \cdot \text{dev}_u(t) + \gamma_{u,k,t}
# $$
#
# $$
# \hat{r}_{u,i,t} = \mu + b_i + b_i(t) + b_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_{u,k}(t), \gamma_{i,k})
# $$
#
# **Optimization**:
#
# $$
# \arg \min_{\alpha, \beta, \gamma} \sum_{u,i} \left(\mu + b_i + b_i(t) + b_u + \alpha_u \cdot \text{dev}_u(t) + f(\gamma_{u,k}(t), \gamma_{i,k}) - R_{u,i} \right)^2 + \lambda \left[ \sum_u \beta_u^2 + \sum_i \beta_i^2 + \sum_i \left\| \gamma_i \right\|_2^2 + \sum_u \left\| \gamma_u \right\|_2^2 \right]
# $$

# %%
from temporal_dynamic import TemporalDynamicModel

# %%
embedding_dim = 90
dense_units = 90
l2_reg = 0.0201
time_bins= 10
model = TemporalDynamicModel(l2_reg, dense_units, embedding_dim, data_query, time_bins)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_root_mean_squared_error", 
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2, 
    decay_steps=1000, 
    decay_rate=0.8
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule))
model.fit(train_data, epochs=500, validation_data=test_data, callbacks=[early_stopping])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.9328 - loss: 0.8692 - regularization_loss: 6.8077 - total_loss: 7.6769 - val_root_mean_squared_error: 0.9034 - val_loss: 0.7082 - val_regularization_loss: 0.0144 - val_total_loss: 0.7226
# Epoch 2/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8856 - loss: 0.7839 - regularization_loss: 0.0209 - total_loss: 0.8048 - val_root_mean_squared_error: 0.8821 - val_loss: 0.6788 - val_regularization_loss: 0.0268 - val_total_loss: 0.7056
# Epoch 3/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8643 - loss: 0.7467 - regularization_loss: 0.0285 - total_loss: 0.7752 - val_root_mean_squared_error: 0.8672 - val_loss: 0.6576 - val_regularization_loss: 0.0310 - val_total_loss: 0.6886
# Epoch 4/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.8454 - loss: 0.7142 - regularization_loss: 0.0419 - total_loss: 0.7562 - val_root_mean_squared_error: 0.8496 - val_loss: 0.6323 - val_regularization_loss: 0.0610 - val_total_loss: 0.6933
# Epoch 5/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.8241 - loss: 0.6790 - regularization_loss: 0.0775 - total_loss: 0.7565 - val_root_mean_squared_error: 0.8328 - val_loss: 0.6050 - val_regularization_loss: 0.0840 - val_total_loss: 0.6890
# Epoch 6/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.8102 - loss: 0.6563 - regularization_loss: 0.0776 - total_loss: 0.7339 - val_root_mean_squared_error: 0.8234 - val_loss: 0.5897 - val_regularization_loss: 0.0710 - val_total_loss: 0.6607
# Epoch 7/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.8018 - loss: 0.6426 - regularization_loss: 0.0648 - total_loss: 0.7075 - val_root_mean_squared_error: 0.8181 - val_loss: 0.5815 - val_regularization_loss: 0.0597 - val_total_loss: 0.6413
# Epoch 8/500
# 227/227 [==============================] - 4s 15ms/step - root_mean_squared_error: 0.7957 - loss: 0.6329 - regularization_loss: 0.0553 - total_loss: 0.6882 - val_root_mean_squared_error: 0.8147 - val_loss: 0.5760 - val_regularization_loss: 0.0516 - val_total_loss: 0.6276
# Epoch 9/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.7909 - loss: 0.6252 - regularization_loss: 0.0484 - total_loss: 0.6736 - val_root_mean_squared_error: 0.8123 - val_loss: 0.5716 - val_regularization_loss: 0.0455 - val_total_loss: 0.6171
# Epoch 10/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7869 - loss: 0.6191 - regularization_loss: 0.0429 - total_loss: 0.6620 - val_root_mean_squared_error: 0.8105 - val_loss: 0.5687 - val_regularization_loss: 0.0407 - val_total_loss: 0.6093
# Epoch 11/500
# 227/227 [==============================] - 3s 15ms/step - root_mean_squared_error: 0.7835 - loss: 0.6137 - regularization_loss: 0.0385 - total_loss: 0.6522 - val_root_mean_squared_error: 0.8091 - val_loss: 0.5663 - val_regularization_loss: 0.0366 - val_total_loss: 0.6029
# Epoch 12/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7804 - loss: 0.6088 - regularization_loss: 0.0350 - total_loss: 0.6438 - val_root_mean_squared_error: 0.8080 - val_loss: 0.5643 - val_regularization_loss: 0.0334 - val_total_loss: 0.5976
# Epoch 13/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7777 - loss: 0.6041 - regularization_loss: 0.0320 - total_loss: 0.6361 - val_root_mean_squared_error: 0.8071 - val_loss: 0.5626 - val_regularization_loss: 0.0306 - val_total_loss: 0.5933
# Epoch 14/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7753 - loss: 0.6005 - regularization_loss: 0.0294 - total_loss: 0.6299 - val_root_mean_squared_error: 0.8064 - val_loss: 0.5613 - val_regularization_loss: 0.0282 - val_total_loss: 0.5895
# Epoch 15/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7730 - loss: 0.5970 - regularization_loss: 0.0272 - total_loss: 0.6241 - val_root_mean_squared_error: 0.8061 - val_loss: 0.5608 - val_regularization_loss: 0.0261 - val_total_loss: 0.5869
# Epoch 16/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7709 - loss: 0.5935 - regularization_loss: 0.0252 - total_loss: 0.6187 - val_root_mean_squared_error: 0.8055 - val_loss: 0.5595 - val_regularization_loss: 0.0244 - val_total_loss: 0.5839
# Epoch 17/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7690 - loss: 0.5912 - regularization_loss: 0.0236 - total_loss: 0.6147 - val_root_mean_squared_error: 0.8050 - val_loss: 0.5586 - val_regularization_loss: 0.0228 - val_total_loss: 0.5814
# Epoch 18/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7673 - loss: 0.5881 - regularization_loss: 0.0221 - total_loss: 0.6102 - val_root_mean_squared_error: 0.8048 - val_loss: 0.5580 - val_regularization_loss: 0.0215 - val_total_loss: 0.5795
# Epoch 19/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7656 - loss: 0.5858 - regularization_loss: 0.0209 - total_loss: 0.6067 - val_root_mean_squared_error: 0.8042 - val_loss: 0.5570 - val_regularization_loss: 0.0203 - val_total_loss: 0.5772
# Epoch 20/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7641 - loss: 0.5834 - regularization_loss: 0.0198 - total_loss: 0.6031 - val_root_mean_squared_error: 0.8042 - val_loss: 0.5569 - val_regularization_loss: 0.0192 - val_total_loss: 0.5761
# Epoch 21/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7627 - loss: 0.5810 - regularization_loss: 0.0187 - total_loss: 0.5998 - val_root_mean_squared_error: 0.8039 - val_loss: 0.5564 - val_regularization_loss: 0.0183 - val_total_loss: 0.5747
# Epoch 22/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7614 - loss: 0.5793 - regularization_loss: 0.0178 - total_loss: 0.5971 - val_root_mean_squared_error: 0.8038 - val_loss: 0.5559 - val_regularization_loss: 0.0174 - val_total_loss: 0.5733
# Epoch 23/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7601 - loss: 0.5772 - regularization_loss: 0.0170 - total_loss: 0.5941 - val_root_mean_squared_error: 0.8035 - val_loss: 0.5552 - val_regularization_loss: 0.0166 - val_total_loss: 0.5718
# Epoch 24/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7589 - loss: 0.5757 - regularization_loss: 0.0163 - total_loss: 0.5919 - val_root_mean_squared_error: 0.8032 - val_loss: 0.5547 - val_regularization_loss: 0.0159 - val_total_loss: 0.5707
# Epoch 25/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7578 - loss: 0.5735 - regularization_loss: 0.0156 - total_loss: 0.5891 - val_root_mean_squared_error: 0.8031 - val_loss: 0.5544 - val_regularization_loss: 0.0153 - val_total_loss: 0.5697
# Epoch 26/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7567 - loss: 0.5720 - regularization_loss: 0.0150 - total_loss: 0.5870 - val_root_mean_squared_error: 0.8029 - val_loss: 0.5540 - val_regularization_loss: 0.0147 - val_total_loss: 0.5687
# Epoch 27/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7557 - loss: 0.5705 - regularization_loss: 0.0144 - total_loss: 0.5850 - val_root_mean_squared_error: 0.8028 - val_loss: 0.5538 - val_regularization_loss: 0.0142 - val_total_loss: 0.5680
# Epoch 28/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7548 - loss: 0.5689 - regularization_loss: 0.0139 - total_loss: 0.5828 - val_root_mean_squared_error: 0.8026 - val_loss: 0.5532 - val_regularization_loss: 0.0137 - val_total_loss: 0.5669
# Epoch 29/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7538 - loss: 0.5678 - regularization_loss: 0.0135 - total_loss: 0.5813 - val_root_mean_squared_error: 0.8025 - val_loss: 0.5532 - val_regularization_loss: 0.0133 - val_total_loss: 0.5665
# Epoch 30/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7530 - loss: 0.5665 - regularization_loss: 0.0131 - total_loss: 0.5796 - val_root_mean_squared_error: 0.8024 - val_loss: 0.5529 - val_regularization_loss: 0.0129 - val_total_loss: 0.5658
# Epoch 31/500
# 227/227 [==============================] - 4s 15ms/step - root_mean_squared_error: 0.7521 - loss: 0.5650 - regularization_loss: 0.0127 - total_loss: 0.5776 - val_root_mean_squared_error: 0.8024 - val_loss: 0.5529 - val_regularization_loss: 0.0125 - val_total_loss: 0.5654
# Epoch 32/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7513 - loss: 0.5640 - regularization_loss: 0.0123 - total_loss: 0.5763 - val_root_mean_squared_error: 0.8023 - val_loss: 0.5528 - val_regularization_loss: 0.0121 - val_total_loss: 0.5649
# Epoch 33/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7505 - loss: 0.5626 - regularization_loss: 0.0120 - total_loss: 0.5745 - val_root_mean_squared_error: 0.8023 - val_loss: 0.5526 - val_regularization_loss: 0.0118 - val_total_loss: 0.5644
# Epoch 34/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7498 - loss: 0.5615 - regularization_loss: 0.0117 - total_loss: 0.5731 - val_root_mean_squared_error: 0.8023 - val_loss: 0.5525 - val_regularization_loss: 0.0115 - val_total_loss: 0.5640
# Epoch 35/500
# 227/227 [==============================] - 4s 15ms/step - root_mean_squared_error: 0.7490 - loss: 0.5607 - regularization_loss: 0.0114 - total_loss: 0.5721 - val_root_mean_squared_error: 0.8023 - val_loss: 0.5524 - val_regularization_loss: 0.0112 - val_total_loss: 0.5636
# Epoch 36/500
# 227/227 [==============================] - 4s 16ms/step - root_mean_squared_error: 0.7483 - loss: 0.5597 - regularization_loss: 0.0111 - total_loss: 0.5707 - val_root_mean_squared_error: 0.8023 - val_loss: 0.5525 - val_regularization_loss: 0.0110 - val_total_loss: 0.5634

# %%
test_metrics = model.evaluate(test_data, return_dict=True)
print(f"Test RMSE: {test_metrics['root_mean_squared_error']}")

predictions = []
actual_ratings = []
for batch in test_data:
    predicted_ratings = model(batch).numpy()
    actual_ratings.extend(batch["rating"].numpy())
    predictions.extend(predicted_ratings)

predictions = np.array(predictions)
actual_ratings = np.array(actual_ratings)

rmse = np.sqrt(np.mean((predictions - actual_ratings) ** 2))
print(f"RECHECK RMSE: {rmse}")

if np.all(actual_ratings == actual_ratings.round()):
    correct = np.mean(predictions.round() == actual_ratings)
    print(f"Rounded Accuracy: {correct}")
else:
    print("Actual ratings are not integers, skipping rounded accuracy calculation.")
# Out:
#  1/57 [..............................] - ETA: 0s - root_mean_squared_error: 0.8852 - loss: 0.7836 - regularization_loss: 0.0147 - total_loss: 0.7983
# 57/57 [==============================] - 0s 8ms/step - root_mean_squared_error: 0.8029 - loss: 0.6424 - regularization_loss: 0.0147 - total_loss: 0.6571
# Test RMSE: 0.8028972148895264
# RECHECK RMSE: 0.8028971318795725
# Rounded Accuracy: 0.5753128412764874

# %% [markdown]
# ***
# # Downstream Recommendation
# ***
