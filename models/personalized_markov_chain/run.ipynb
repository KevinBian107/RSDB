# %% [markdown]
# # Running Models

# %%
# %load_ext autoreload
# %autoreload 2

import gzip
from collections import defaultdict
import math
import numpy as np
import string
import random
import string
from pathlib import Path

import tensorflow as tf
import tensorflow_recommenders as tfrs
import pandas as pd
import keras_tuner as kt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ***
# # Description
# ***
#
# # Factorized Personalized Markov Chain
#
# $$
# p(i_{t+1} \mid i_t, u) = p(i_{t+1} \mid i_t, u)
# $$
#
# In Factorized Personalized Markov Chain (FPMC), we do this calculation by:
#
# $$
# f(i \mid u, j) = \underbrace{\gamma_{ui} \cdot \gamma_{iu}}_{\mathclap{f(i \mid u)}} + \underbrace{\gamma_{ij} \cdot \gamma_{ji}}_{\mathclap{f(i \mid j)}} + \underbrace{\gamma_{uj} \cdot \gamma_{ju}}_{\mathclap{f(u, j)}}.
# $$
#
# Neglecting independent terms:
#
# $$
# f(i \mid u, j) =
# \underbrace{\gamma_{ui} \cdot \gamma_{iu}}_{\text{user's compatibility with the next item}} +
# \underbrace{\gamma_{ij} \cdot \gamma_{ji}}_{\text{next item's compatibility with the previous item}}
# $$

# %%
from fpmc import FPMCModel

# %%
base_path = Path.cwd().parent.parent
meta_file_path = base_path / "data" / "california_clean_metadata.json.gz"
data_path = base_path / "data" / "california_clean_data.json.gz"

meta_df = pd.read_json(meta_file_path, compression = 'gzip', lines = True)
df = pd.read_json(data_path, compression = 'gzip', lines = True)
df = df.reset_index()

merged_df = df.merge(meta_df, on='gmap_id', how='inner')
columns_to_remove = [col for col in df.columns if col.endswith('_y')]
merged_clean = df.drop(columns=columns_to_remove)

data_query = merged_clean[['gmap_id', 'reviewer_id', 'rating']]
merged_clean["gmap_id"] = merged_clean["gmap_id"].astype(str)
merged_clean["reviewer_id"] = merged_clean["reviewer_id"].astype(str)

merged_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1158336 entries, 0 to 1158335
# Data columns (total 21 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   index              1158336 non-null  int64
#  1   reviewer_id        1158336 non-null  object
#  2   reviewer_name      1158336 non-null  object
#  3   review_time(unix)  1158336 non-null  int64
#  4   rating             1158336 non-null  int64
#  5   text               650897 non-null   object
#  6   resp               73022 non-null    object
#  7   gmap_id            1158336 non-null  object
#  8   has_rep            1158336 non-null  bool
#  9   gmap_name          1158336 non-null  object
#  10  address            1158336 non-null  object
#  11  latitude           1158336 non-null  float64
#  12  longitude          1158336 non-null  float64
#  13  description        838359 non-null   object
#  14  category           1158336 non-null  object
#  15  avg_rating         1158336 non-null  float64
#  16  num_of_reviews     1158336 non-null  int64
#  17  price              591411 non-null   object
#  18  hours              1065012 non-null  object
#  19  MISC               1131206 non-null  object
#  20  relative_results   1158336 non-null  object
# dtypes: bool(1), float64(3), int64(4), object(13)
# memory usage: 177.9+ MB

# %%
# Sort data by user and timestamp and reate sequences
data = merged_clean.sort_values(by=["reviewer_id", "review_time(unix)"])
data["prev_item_id"] = data.groupby("reviewer_id")["gmap_id"].shift(1)
data = data.dropna(subset=["prev_item_id"])

# Instantiate StringLookup layers
user_lookup = tf.keras.layers.StringLookup(
    vocabulary=data_query["reviewer_id"].unique(), mask_token=None
)
item_lookup = tf.keras.layers.StringLookup(
    vocabulary=data_query["gmap_id"].unique(), mask_token=None
)

# Apply StringLookup to the dataset
def df_to_tf_dataset(df):
    return tf.data.Dataset.from_tensor_slices({
        "reviewer_id": user_lookup(df["reviewer_id"]),
        "prev_item_id": item_lookup(df["prev_item_id"]),
        "next_item_id": item_lookup(df["gmap_id"]),
        "rating": df["rating"].astype(float),
    })

train_df = data.sample(frac=0.8, random_state=42)
test_df = data.drop(train_df.index)

train_data = df_to_tf_dataset(train_df).shuffle(1024).batch(4096)
test_data = df_to_tf_dataset(test_df).batch(4096)

train_df.sample(3)
# Out:
#          index             reviewer_id reviewer_name  review_time(unix)  \
# 85136    85136         1.065456092e+20       redwine      1530505857212
# 703347  703347         1.099487128e+20  Analu Morris      1559406429033
# 692075  692075  1.0098099140000001e+20       chan an      1523495350593
#
#         rating                                               text  resp  \
# 85136        5  (Translated by Google) This is the 8th time th...  None
# 703347       5                                               None  None
# 692075       4  (Translated by Google) I went on a company tri...  None
#
#                                       gmap_id  has_rep  \
# 85136   0x7c006d8a4c2dd1ab:0xe200a1829f0437e9    False
# 703347  0x7c001265ac2c9e61:0x10baeee14a815372    False
# 692075  0x7c006d80a119ccfd:0xa67649fe6e24a623    False
#
#                                       gmap_name  ...   longitude  \
# 85136                   Four Paddle Condominium  ... -157.829240
# 703347  Bubbies Homemade Ice Cream and Desserts  ... -157.704846
# 692075              Side Street Inn On Da Strip  ... -157.814106
#
#                                               description  \
# 85136                                                None
# 703347  Casual, counter-serve joint featuring mochi ic...
# 692075  No-frills eatery is a buzzy stop for American ...
#
#                               category avg_rating num_of_reviews  price  \
# 85136                          [Hotel]        4.4             68   None
# 703347  [Ice cream shop, Dessert shop]        4.5            378     $$
# 692075                    [Restaurant]        4.6            943     $$
#
#                                                     hours  \
# 85136                                                None
# 703347  [[Tuesday, 10AM–11PM], [Wednesday, 10AM–11PM],...
# 692075  [[Tuesday, 4–9PM], [Wednesday, 4–9PM], [Thursd...
#
#                                                      MISC  \
# 85136                                                None
# 703347  {'Accessibility': ['Wheelchair accessible park...
# 692075  {'Service options': ['Curbside pickup', 'Deliv...
#
#                                          relative_results  \
# 85136   [0x7c006d89cc6ab0c3:0x356d5cfd0e454750, 0x7c00...
# 703347  [0x7c006e741cc3c1e3:0x5ee37990fd95cdda, 0x7c00...
# 692075  [0x7c006e08c20839b5:0x35691945f7610652, 0x7c00...
#
#                                  prev_item_id
# 85136   0x7c006e6de49e8a1f:0xa44b7af81f555ead
# 703347  0x7c0012675bf5ab2b:0x295c3d9f236971f7
# 692075  0x7c00660d84ab0d0b:0x1ae443215ed5b146
#
# [3 rows x 22 columns]

# %%
embedding_dim = 90
l2_reg = 0.0201
lr = 1e-3
model = FPMCModel(l2_reg=l2_reg, embedding_dim=embedding_dim, data_query=data_query)

# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=1e-4,
#     decay_steps=10000,
#     decay_rate=0.9
# )

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_root_mean_squared_error", 
    patience=10,
    min_delta=0.001,
    restore_best_weights=True
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr))

history = model.fit(
    train_data, 
    validation_data=test_data, 
    epochs=50, 
    callbacks=[early_stopping]
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 214/214 [==============================] - 3s 12ms/step - root_mean_squared_error: 1.1519 - loss: 1.3257 - regularization_loss: 8.0836 - total_loss: 9.4093 - val_root_mean_squared_error: 1.0529 - val_loss: 1.1110 - val_regularization_loss: 3.8061e-08 - val_total_loss: 1.1110
# Epoch 2/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.9914 - loss: 0.9825 - regularization_loss: 3.7810e-09 - total_loss: 0.9825 - val_root_mean_squared_error: 0.9435 - val_loss: 0.9025 - val_regularization_loss: 9.9112e-09 - val_total_loss: 0.9025
# Epoch 3/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.9121 - loss: 0.8316 - regularization_loss: 3.0781e-08 - total_loss: 0.8316 - val_root_mean_squared_error: 0.8936 - val_loss: 0.8184 - val_regularization_loss: 1.8978e-07 - val_total_loss: 0.8184
# Epoch 4/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.8743 - loss: 0.7643 - regularization_loss: 9.2294e-08 - total_loss: 0.7643 - val_root_mean_squared_error: 0.8696 - val_loss: 0.7811 - val_regularization_loss: 8.9214e-08 - val_total_loss: 0.7811
# Epoch 5/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.8532 - loss: 0.7280 - regularization_loss: 1.4421e-07 - total_loss: 0.7280 - val_root_mean_squared_error: 0.8552 - val_loss: 0.7593 - val_regularization_loss: 2.6003e-07 - val_total_loss: 0.7593
# Epoch 6/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.8384 - loss: 0.7029 - regularization_loss: 8.9977e-07 - total_loss: 0.7029 - val_root_mean_squared_error: 0.8448 - val_loss: 0.7431 - val_regularization_loss: 6.2205e-07 - val_total_loss: 0.7431
# Epoch 7/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.8266 - loss: 0.6835 - regularization_loss: 5.9477e-07 - total_loss: 0.6835 - val_root_mean_squared_error: 0.8365 - val_loss: 0.7296 - val_regularization_loss: 7.3921e-07 - val_total_loss: 0.7296
# Epoch 8/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.8167 - loss: 0.6669 - regularization_loss: 1.1296e-06 - total_loss: 0.6669 - val_root_mean_squared_error: 0.8296 - val_loss: 0.7182 - val_regularization_loss: 1.4689e-06 - val_total_loss: 0.7182
# Epoch 9/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.8081 - loss: 0.6531 - regularization_loss: 1.2574e-06 - total_loss: 0.6531 - val_root_mean_squared_error: 0.8239 - val_loss: 0.7084 - val_regularization_loss: 1.3821e-06 - val_total_loss: 0.7084
# Epoch 10/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.8006 - loss: 0.6410 - regularization_loss: 1.6778e-06 - total_loss: 0.6410 - val_root_mean_squared_error: 0.8191 - val_loss: 0.7001 - val_regularization_loss: 1.7895e-06 - val_total_loss: 0.7001
# Epoch 11/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7941 - loss: 0.6306 - regularization_loss: 1.9171e-06 - total_loss: 0.6306 - val_root_mean_squared_error: 0.8151 - val_loss: 0.6929 - val_regularization_loss: 2.1388e-06 - val_total_loss: 0.6929
# Epoch 12/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7884 - loss: 0.6216 - regularization_loss: 2.3037e-06 - total_loss: 0.6216 - val_root_mean_squared_error: 0.8117 - val_loss: 0.6868 - val_regularization_loss: 2.4232e-06 - val_total_loss: 0.6868
# Epoch 13/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7834 - loss: 0.6139 - regularization_loss: 2.6635e-06 - total_loss: 0.6139 - val_root_mean_squared_error: 0.8089 - val_loss: 0.6815 - val_regularization_loss: 2.8357e-06 - val_total_loss: 0.6815
# Epoch 14/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7790 - loss: 0.6068 - regularization_loss: 3.0429e-06 - total_loss: 0.6068 - val_root_mean_squared_error: 0.8065 - val_loss: 0.6771 - val_regularization_loss: 3.2473e-06 - val_total_loss: 0.6771
# Epoch 15/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.7751 - loss: 0.6009 - regularization_loss: 3.4746e-06 - total_loss: 0.6009 - val_root_mean_squared_error: 0.8046 - val_loss: 0.6733 - val_regularization_loss: 3.6663e-06 - val_total_loss: 0.6733
# Epoch 16/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.7717 - loss: 0.5955 - regularization_loss: 3.9185e-06 - total_loss: 0.5955 - val_root_mean_squared_error: 0.8029 - val_loss: 0.6701 - val_regularization_loss: 4.1742e-06 - val_total_loss: 0.6701
# Epoch 17/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7687 - loss: 0.5909 - regularization_loss: 4.3899e-06 - total_loss: 0.5909 - val_root_mean_squared_error: 0.8016 - val_loss: 0.6674 - val_regularization_loss: 4.6076e-06 - val_total_loss: 0.6674
# Epoch 18/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7660 - loss: 0.5867 - regularization_loss: 4.9168e-06 - total_loss: 0.5867 - val_root_mean_squared_error: 0.8005 - val_loss: 0.6651 - val_regularization_loss: 5.1959e-06 - val_total_loss: 0.6651
# Epoch 19/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7636 - loss: 0.5830 - regularization_loss: 5.4799e-06 - total_loss: 0.5830 - val_root_mean_squared_error: 0.7996 - val_loss: 0.6632 - val_regularization_loss: 5.7967e-06 - val_total_loss: 0.6632
# Epoch 20/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7614 - loss: 0.5797 - regularization_loss: 6.0577e-06 - total_loss: 0.5797 - val_root_mean_squared_error: 0.7989 - val_loss: 0.6616 - val_regularization_loss: 6.5181e-06 - val_total_loss: 0.6616
# Epoch 21/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7595 - loss: 0.5770 - regularization_loss: 6.7307e-06 - total_loss: 0.5770 - val_root_mean_squared_error: 0.7983 - val_loss: 0.6603 - val_regularization_loss: 7.0665e-06 - val_total_loss: 0.6603
# Epoch 22/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7578 - loss: 0.5743 - regularization_loss: 7.4364e-06 - total_loss: 0.5743 - val_root_mean_squared_error: 0.7979 - val_loss: 0.6592 - val_regularization_loss: 7.7812e-06 - val_total_loss: 0.6592
# Epoch 23/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.7563 - loss: 0.5721 - regularization_loss: 8.1955e-06 - total_loss: 0.5721 - val_root_mean_squared_error: 0.7976 - val_loss: 0.6583 - val_regularization_loss: 8.6150e-06 - val_total_loss: 0.6583
# Epoch 24/50
# 214/214 [==============================] - 2s 11ms/step - root_mean_squared_error: 0.7550 - loss: 0.5700 - regularization_loss: 9.0249e-06 - total_loss: 0.5700 - val_root_mean_squared_error: 0.7973 - val_loss: 0.6576 - val_regularization_loss: 9.4998e-06 - val_total_loss: 0.6576
# Epoch 25/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7538 - loss: 0.5681 - regularization_loss: 9.9219e-06 - total_loss: 0.5681 - val_root_mean_squared_error: 0.7972 - val_loss: 0.6571 - val_regularization_loss: 1.0360e-05 - val_total_loss: 0.6571
# Epoch 26/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7527 - loss: 0.5665 - regularization_loss: 1.0864e-05 - total_loss: 0.5665 - val_root_mean_squared_error: 0.7971 - val_loss: 0.6566 - val_regularization_loss: 1.1389e-05 - val_total_loss: 0.6566
# Epoch 27/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7517 - loss: 0.5650 - regularization_loss: 1.1913e-05 - total_loss: 0.5650 - val_root_mean_squared_error: 0.7971 - val_loss: 0.6563 - val_regularization_loss: 1.2453e-05 - val_total_loss: 0.6563
# Epoch 28/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7508 - loss: 0.5637 - regularization_loss: 1.3020e-05 - total_loss: 0.5637 - val_root_mean_squared_error: 0.7971 - val_loss: 0.6560 - val_regularization_loss: 1.3535e-05 - val_total_loss: 0.6560
# Epoch 29/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7500 - loss: 0.5625 - regularization_loss: 1.4232e-05 - total_loss: 0.5625 - val_root_mean_squared_error: 0.7971 - val_loss: 0.6558 - val_regularization_loss: 1.4827e-05 - val_total_loss: 0.6558
# Epoch 30/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7493 - loss: 0.5615 - regularization_loss: 1.5496e-05 - total_loss: 0.5615 - val_root_mean_squared_error: 0.7972 - val_loss: 0.6557 - val_regularization_loss: 1.6150e-05 - val_total_loss: 0.6557
# Epoch 31/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7487 - loss: 0.5605 - regularization_loss: 1.6872e-05 - total_loss: 0.5605 - val_root_mean_squared_error: 0.7973 - val_loss: 0.6556 - val_regularization_loss: 1.7541e-05 - val_total_loss: 0.6556
# Epoch 32/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7481 - loss: 0.5597 - regularization_loss: 1.8339e-05 - total_loss: 0.5597 - val_root_mean_squared_error: 0.7974 - val_loss: 0.6556 - val_regularization_loss: 1.9031e-05 - val_total_loss: 0.6556
# Epoch 33/50
# 214/214 [==============================] - 2s 10ms/step - root_mean_squared_error: 0.7476 - loss: 0.5588 - regularization_loss: 1.9930e-05 - total_loss: 0.5588 - val_root_mean_squared_error: 0.7975 - val_loss: 0.6555 - val_regularization_loss: 2.0776e-05 - val_total_loss: 0.6556

# %% [markdown]
# Evaluation

# %%
test_metrics = model.evaluate(test_data, return_dict=True)
print(f"Test RMSE: {test_metrics['root_mean_squared_error']}")

predictions = []
actual_ratings = []
for batch in test_data:
    predicted_ratings = model(batch).numpy()
    actual_ratings.extend(batch["rating"].numpy())
    predictions.extend(predicted_ratings)

predictions = np.array(predictions)
actual_ratings = np.array(actual_ratings)

rmse = np.sqrt(np.mean((predictions - actual_ratings) ** 2))
print(f"RECHECK RMSE: {rmse}")

if np.all(actual_ratings == actual_ratings.round()):
    correct = np.mean(predictions.round() == actual_ratings)
    print(f"Rounded Accuracy: {correct}")
else:
    print("Actual ratings are not integers, skipping rounded accuracy calculation.")
# Out:
# 54/54 [==============================] - 0s 5ms/step - root_mean_squared_error: 0.7976 - loss: 0.6367 - regularization_loss: 8.6150e-06 - total_loss: 0.6368
# Test RMSE: 0.7975631356239319
# RECHECK RMSE: 0.7975630972223813
# Rounded Accuracy: 0.5646894294972281
